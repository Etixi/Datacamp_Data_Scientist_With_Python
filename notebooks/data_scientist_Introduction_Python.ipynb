# %% [markdown]
# ##**COURS INTERACTIF: Introduction à Python**
#
# + *4 heures*
# + *11 Vidéos*
# + *57 exercices*
# + *4 963 544 Participants*
# + *4 700 XP*
#
# <img src="https://www.datacamp.com/statement-of-accomplishment/badge/course/db7696737d3ae9582b7cdc20b2f88556a82adeb4.png"/>
#
# ###**Description du cours**
#
# + **Python** est un langage de programmation polyvalent qui devient de plus en plus populaire pour la science des données.
#
# + Les entreprises du monde entier utilisent Python pour récolter des informations à partir de leurs données et obtenir un avantage concurrentiel.
#
# + Contrairement à d'autres tutoriels Python, ce cours se concentre sur Python spécifiquement pour la science des données.
#
# + Dans notre cours d'introduction à Python, vous découvrirez des moyens puissants de stocker et de manipuler les données, ainsi que des outils de science des données utiles pour commencer à mener vos propres analyses.
#
#
#
# ####**CHAP I: Les bases de Python**
#
#
# + Une introduction aux concepts de base de Python. Apprenez à utiliser Python de manière interactive et à l'aide d'un script.
#
# + Créez vos premières variables et familiarisez-vous avec les types de données de base de Python.
#
#
# |Obejectifs|
# |----------|
# |**Bonjour Python !**|
# |**interface Python**|
# |**Quand utiliser Python ?**|
# |**Des commentaires ?**|
# |**Python comme calculatrice**|
# |**Variables et types**|
# |**Affectation des variables**|
# |**Calculs avec des variables**|
# |**Autres types de variables**|
# |**Devinez le type**|
# |**Opérations avec d'autres types**|
# |**Conversion de type**|
# |**Python peut-il tout gérer ?**|
#
#
# ####**CHAPII: Listes Python**
#
#
# + Apprenez à stocker, accéder et manipuler des données dans des listes : la première étape pour travailler efficacement avec d'énormes quantités de données.
#
# |Objectifs|
# |---------|
# |**Listes Python**|
# |**Créer une liste**|
# **Créer une liste avec différents types**
# **Sélectionner une liste valide**
# **Liste de listes**
# **Sous-ensemble de listes**
# **Sous-ensemble et conquête**
# **Sous-ensemble et calcul**
# **Découpage en tranches et en dés**
# **Découpage en tranches et en dés (2)**
# **Sous-ensemble de listes de listes**
# **Manipulation de listes**
# **Remplacer des éléments de listes**
# **Étendre une liste**
# **Supprimer des éléments de liste**
# **Fonctionnement interne des listes**
#
#
# ####**CHAP III : Fonctions et paquets**
#
# Vous apprendrez à utiliser les fonctions, les méthodes et les packages pour exploiter efficacement le code que de brillants développeurs Python ont écrit. L'objectif est de réduire la quantité de code dont vous avez besoin pour résoudre des problèmes difficiles !
#
# |Objectifs|
# |---------|
# |**Fonctions**|
# |**Fonctions familières**|
# |**Arguments multiples**|
# |**Méthodes**|
# |**Méthodes pour les chaînes de caractères**|
# |**Méthodes pour les listes**|
# |**Méthodes par liste (2)**|
# |**paquet**|
# |**Importer un paquet**|
# |**Importation sélective**|
# |**Différentes manières d'importer**|
#
#
# ####**CHAP IV : NumPy**
#
# + NumPy est un package Python fondamental pour pratiquer efficacement la science des données.
#
# + Apprenez à travailler avec les outils puissants du tableau NumPy et lancez-vous dans l'exploration des données.
#
#
# |NumPy|
# |-----|
# |**Votre premier tableau NumPy**|
# **Taille des joueurs de baseball**
# **IMC d'un joueur de baseball**
# **Poids des joueurs de baseball légers**
# **Effets secondaires de NumPy**
# **Sous-ensemble de tableaux NumPy**
# **Tableaux NumPy 2D**
# **Votre premier tableau NumPy 2D**
# **Données de baseball sous forme 2D**
# **Sous-ensemble de tableaux NumPy 2D**
# **Arithmétique en 2D**
# **NumPy : Statistiques de base**
# **Moyenne et médiane**
# **Explorer les données du baseball**
# **Mélangez le tout**

# %% [markdown]
# ###**Bases De Données**

# %%
baseball = pd.read_csv("/content/baseball.csv")
baseball.head()
# Out:
#               Name Team       Position  Height  Weight    Age PosCategory
# 0    Adam_Donachie  BAL        Catcher      74     180  22.99     Catcher
# 1        Paul_Bako  BAL        Catcher      74     215  34.69     Catcher
# 2  Ramon_Hernandez  BAL        Catcher      72     210  30.78     Catcher
# 3     Kevin_Millar  BAL  First_Baseman      72     210  35.43   Infielder
# 4      Chris_Gomez  BAL  First_Baseman      73     188  35.71   Infielder

# %%
fifa = pd.read_csv("/content/fifa.csv")
fifa.head()
# Out:
#        id                     name   rating  position   height    foot   rare  \
# 0    1001             Gábor Király       69        GK      191   Right      0
# 1  100143             Frederik Boi       65         M      184   Right      0
# 2  100264          Tomasz Szewczuk       57         A      185   Right      0
# 3  100325   Steeve Joseph-Reinette       63         D      180    Left      0
# 4  100326             Kamel Chafni       72         M      181   Right      0
#
#    pace  shooting  passing  dribbling  defending  heading  diving  handling  \
# 0                                                              70        66
# 1    61        65       63         59         62       62
# 2    65        54       43         53         55       74
# 3    68        38       51         46         64       71
# 4    75        64       67         72         57       66
#
#    kicking  reflexes  speed   positioning
# 0       63        74     35          66.0
# ...

# %% [markdown]
# ####**1. Bonjour Python !**
# + Bonjour, je m'appelle Hugo et je serai votre hôte pour Introduction à Python pour la science des données.
# + Je suis data scientist et éducateur chez DataCamp et hôte du podcast DataFramed, que vous devez consulter.
#
# ####**2. Comment allez-vous apprendre**
#
# + Dans ce cours, vous apprendrez Python pour la science des données à travers des leçons vidéo, comme celle-ci, et des exercices interactifs. + Vous obtenez votre propre session Python où vous pouvez expérimenter et essayer de trouver le bon code pour résoudre les instructions.
# + Vous apprenez en faisant, tout en recevant des commentaires personnalisés et instantanés sur votre travail.
#
# ####**3.Python**
# + Python a été conçu par Guido Van Rossum. Ici, vous pouvez voir une photo de moi avec Guido.
# + Ce qui a commencé comme un projet de loisir est rapidement devenu un langage de programmation à usage général :
#   + de nos jours, vous pouvez utiliser Python pour créer pratiquement n'importe quel logiciel.
#   + mais comment est-ce arrivé?
#   + Eh bien, tout d'abord, Python est open source. C'est gratuit.
#
# + Deuxièmement, il est très facile de créer des packages en Python, c'est-à-dire du code que vous pouvez partager avec d'autres personnes pour résoudre des problèmes spécifiques.
#
# + Au fil du temps, de plus en plus de ces packages spécialement conçus pour la science des données ont été développés.
#
# + Supposons que vous souhaitiez créer des visualisations sophistiquées des ventes de votre entreprise.
#
# + Il y a un forfait pour ça. Ou que diriez-vous de vous connecter à une base de données pour analyser les mesures des capteurs ? Il y a aussi un forfait pour ça.
#
# + Les gens se réfèrent souvent à Python comme au couteau suisse des langages de programmation, car vous pouvez presque tout faire avec.
#
# + Dans ce cours, nous commencerons à développer petit à petit vos compétences en matière de codage en science des données, alors assurez-vous de rester dans les parages pour voir à quel point le langage peut être puissant.
#
# + Nos cours se concentrent sur Python 3. Pour installer Python 3 sur votre propre système, suivez les étapes à cette URL.
#
# ####**4. Coque IPython**
# Maintenant que vous êtes tous yeux et oreilles pour Python, commençons à expérimenter. je vais commencer par le
#
# ####**5. Coque IPython**
# Shell Python, un endroit où vous pouvez taper du code Python et voir immédiatement les résultats. Dans l'interface d'exercice de DataCamp, ce shell est intégré ici. Commençons simplement et utilisons Python comme calculatrice.
#
# ####**6. Coque IPython**
# + Permettez-moi de taper 4 + 5 et appuyez sur Entrée.
# + Python interprète ce que vous avez tapé et affiche le résultat de votre calcul, 9.
# + Le shell Python utilisé ici n'est en fait pas celui d'origine ; nous utilisons IPython, abréviation de Interactive Python, qui est une sorte de version optimisée de Python normal qui sera utile plus tard.
# + IPython a été créé par Fernando Pérez et fait partie de l'écosystème Jupyter plus large.
# + En plus de travailler de manière interactive avec Python, vous pouvez également faire exécuter Python ce qu'on appelle
#
# ####**7. Script Python**
# + **scripts python.**
# + Ces scripts python sont simplement des fichiers texte avec l'extension (point) py.
# +  Il s'agit essentiellement d'une liste de commandes Python qui sont exécutées, presque comme si vous tapiez vous-même les commandes dans le shell, ligne par ligne.
#
# ####**8. Script Python**
# + Mettons maintenant la commande d'avant dans un script, qui peut être trouvé ici dans l'interface de DataCamp.
# + L'étape suivante consiste à exécuter le script en cliquant sur "Soumettre la réponse".
# + Si vous exécutez ce script dans l'interface DataCamp, il n'y a rien dans le volet de sortie.
# + En effet, vous devez utiliser explicitement print inside scripts si vous souhaitez générer une sortie lors de l'exécution.
#
# ####**9. Script Python**
# + Enveloppons notre calcul précédent dans un appel print et réexécutons le script.
# + Cette fois, la même sortie qu'auparavant est générée, super ! Mettre votre code dans des scripts Python au lieu de retaper manuellement chaque étape de manière interactive vous aidera à garder la structure et à éviter de tout retaper encore et encore si vous souhaitez apporter une modification ; vous faites simplement le changement dans le script et réexécutez le tout.
#
# ####**10. Interface DataCamp**
# + Maintenant que vous avez une idée des différentes manières de travailler avec Python, je vous suggère de passer aux exercices. + Utilisez le shell IPython pour l'expérimentation et utilisez l'éditeur de script Python pour coder la réponse réelle.
# + Si vous cliquez sur Soumettre la réponse, votre script sera exécuté et son exactitude vérifiée.
#
# ####**11. Entraînons-nous !**
# Obtenez le codage et n'oubliez pas de vous amuser!

# %% [markdown]
# ###**Exercice**
#
# ####**L'interface Python**
# + Dans le script Python sur la droite, vous pouvez taper du code Python pour résoudre les exercices. Si vous cliquez sur Run Code ou Submit Answer , votre script python ( script.py) est exécuté et la sortie est affichée dans le shell IPython. Soumettre la réponse vérifie si votre soumission est correcte et vous donne des commentaires.
#
# + + Vous pouvez cliquer sur Exécuter le code et soumettre la réponse aussi souvent que vous le souhaitez. Si vous êtes bloqué, vous pouvez cliquer sur Get Hint , puis sur Get Solution .
#
# + Vous pouvez également utiliser le shell IPython de manière interactive en tapant simplement des commandes et en appuyant sur Entrée. Lorsque vous travaillez directement dans le shell, l'exactitude de votre code ne sera pas vérifiée, c'est donc un excellent moyen d'expérimenter.
#
# ###**Des instructions**
#
# + Expérimentez dans le shell IPython ; tapez 5 / 8, par exemple.
#
# + Ajoutez une autre ligne de code au script Python en haut à droite (pas dans le Shell) : print(7 + 10).
#
# + Appuyez sur Soumettre la réponse pour exécuter le script Python et recevoir des commentaires.

# %%
# Example, do not modify!
print(5 / 8) # <- division euclidienne

# Print the sum of 7 and 10
print(7+10)  # <- somme
# Out:
# 0.625
# 17

# %% [markdown]
# ####**Quand utiliser Python ?**
# Python est un langage assez polyvalent. Pour quelles applications pouvez-vous utiliser Python ?
#
# ####**Des instructions**
#
# ####**Des réponses possibles**
#
# + Vous voulez faire quelques calculs rapides.
#
# + Pour votre nouvelle entreprise, vous souhaitez développer un site Web basé sur une base de données.
#
# + Votre patron vous demande de nettoyer et d'analyser les résultats de la dernière enquête de satisfaction.
#
# + **Tout ce qui précède.**

# %% [markdown]
# ####**Des commentaires ?**
# + Ce qu'Hugo n'a pas mentionné dans ses vidéos, c'est que vous pouvez ajouter des commentaires à vos scripts Python. Les commentaires sont importants pour vous assurer que vous et les autres pouvez comprendre de quoi parle votre code.
#
# + Pour ajouter des commentaires à votre script Python, vous pouvez utiliser la #balise. Ces commentaires ne sont pas exécutés en tant que code Python, ils n'influenceront donc pas votre résultat. Prenons par exemple le commentaire dans l'éditeur, # Division; il est complètement ignoré lors de l'exécution.
#
# ####**Des instructions**
#
# + Au-dessus du print(7 + 10),
#   + ajoutez le commentaire
#         # Addition

# %%
# Division
print(5 / 8)

#Addition
print(7 + 10)

# %% [markdown]
# ####**Python comme calculatrice**
# + Python est parfaitement adapté pour effectuer des calculs de base. Outre l'addition, la soustraction, la multiplication et la division, il existe également un support pour des opérations plus avancées telles que :
#
# + Exponentation : **.
#   + Cet opérateur élève le nombre à sa gauche à la puissance du nombre à sa droite.
#     + Par exemple 4**2donnera 16.
#
# + Modulo : %.
#   + Cet opérateur renvoie le reste de la division du nombre à gauche par le nombre à sa droite.
#     + Par exemple 18 % 7égal à 4.
# Le code du script donne quelques exemples.
#
# ####**Des instructions**
#
# + Supposons que vous ayez 100 $, que vous pouvez investir avec un rendement de 10 % chaque année.
#
# + Au bout d'un an, c'est
#       100*1,1= 110 dollars,
# + et après deux ans, c'est
#       100*1,1*1,1 = 121.
#
# + Ajoutez un code pour calculer combien d'argent vous vous retrouvez après 7 ans et imprimez le résultat.

# %%
# Addition, subtraction
#print(5 + 5)
#print(5 - 5)

# Multiplication, division, modulo, and exponentiation
print(3 * 5) # <-
print(10 / 2)
print(18 % 7)
print(4 ** 2)

# How much is your $100 worth after 7 years?
#print(100*1.1**7)
# Out:
# 15
# 5.0
# 4
# 16

# %% [markdown]
# ##**Variables et types**

# %% [markdown]
# ###**1. Variables et types**
# + Bravo et bienvenue ! Il est clair que Python est une excellente calculatrice.
#
# + Cependant, si vous souhaitez effectuer des calculs plus complexes, vous souhaiterez "enregistrer" les valeurs pendant que vous codez.

# %% [markdown]
# ###**2. variables**
# + Vous pouvez le faire en définissant une variable, avec un nom spécifique sensible à la casse.
#
# + Une fois que vous avez créé (ou déclaré) une telle variable, vous pouvez ensuite appeler sa valeur en tapant le nom de la variable.
#
# + Supposons que vous mesuriez votre taille et votre poids, en unités métriques :
#   + vous mesurez 1 point 79 mètres
#   + et pesez 68 points 7 kilogrammes.
#
# + Vous pouvez affecter ces valeurs à deux variables, nommées hauteur et poids, avec un signe égal : si vous tapez maintenant le nom de la variable, hauteur, Python recherche le nom de la variable, récupère sa valeur et l'imprimer

# %%
height = 1.79
weight = 68.7
height
# Out:
# 1.79

# %% [markdown]
# ###**3. Calculer l'IMC**
#
# + Calculons maintenant l'indice de masse corporelle, ou IMC, qui est calculé comme suit, avec le poids en kilogrammes et la taille en mètres.
#
# + Vous pouvez le faire avec les valeurs réelles, mais vous pouvez tout aussi bien utiliser les variables taille et poids, comme ici.
#
# + Chaque fois que vous tapez le nom de la variable, vous demandez à Python de le remplacer par la valeur réelle de la variable.
#
# + le poids correspond à 68.7 et la taille à 1.79.
#
# + Enfin, dans cette version, Python stocke le résultat dans une nouvelle variable, bmi.
#
# + bmi contient maintenant la même valeur que celle que vous avez calculée précédemment.
#
# + En Python, les variables sont utilisées tout le temps. Ils contribuent à rendre votre code reproductible.

# %%
# Calculate BMI = weight/height²
height = 1.79
weight = 68.7
# height

# %%
68.7/1.79**2
# Out:
# 21.44127836209856

# %%
weight/height**2
# Out:
# 21.44127836209856

# %% [markdown]
# $$BMI = \frac{weight}{height^2}$$

# %%
bmi = weight/height**2
bmi
# Out:
# 21.44127836209856

# %% [markdown]
# ###**4. Reproductibilité**
#
# + Supposons que le code pour créer la taille, le poids et la variable bmi soit dans un script, comme celui-ci.
#
# + Si vous voulez maintenant recalculer l'IMC pour un autre poids,

# %%
# Reproducibility
height = 1.79
weight = 68.7
bmi = weight/height**2
print(bmi)
# Out:
# 21.44127836209856

# %% [markdown]
# ###**5. Reproductibilité**
#
# + vous pouvez simplement modifier la déclaration de la variable de poids et relancer le script.
#
# + L'IMC change en conséquence, car la valeur du poids variable a également changé. Jusqu'à présent, nous n'avons travaillé qu'avec des valeurs numériques, telles que la taille et le poids.

# %%
height = 1.79
weight = 74.2# <-
bmi = weight / height ** 2
print(bmi)
# Out:
# 21.44127836209856

# %% [markdown]
# ###**6. Types Python**
#
# + En Python, ces nombres ont tous un type spécifique.
#
# + Vous pouvez vérifier le type d'une valeur avec la fonction type. Pour voir le type de notre valeur bmi, écrivez simplement type puis bmi entre parenthèses.
#
# + Vous pouvez voir qu'il s'agit d'un **flottant**, qui est la façon dont Python représente un nombre réel, donc un nombre qui peut avoir à la fois une partie entière et une partie fractionnaire.
#
# + Python a aussi un type pour les entiers : **int**, comme cet exemple.
#
# + Cependant, pour faire de la science des données, vous aurez besoin de plus que des **entiers et des flottants.**

# %%
type(bmi)
# Out:
# float

# %%
day_of_week = 5
type(day_of_week)
# Out:
# int

# %% [markdown]
# ###**7. Types Python (2)**
#
# + Python propose des tonnes d'autres types de données.
#
# + Les plus courants sont **les chaînes et les booléens.**
#
# + **Une chaîne est la façon dont Python représente du texte.**
#
# + Vous pouvez utiliser à la fois des **guillemets doubles et simples** pour créer une chaîne, comme vous pouvez le voir dans ces exemples.
#
# + Si vous imprimez le type de la dernière variable ici, vous voyez qu'il s'agit de str, abréviation de string.
#
# + Le booléen est un type qui peut être vrai ou faux.
#
# + Vous pouvez y penser comme « Oui » et « Non » dans le langage courant.
#
# + Les booléens seront très utiles dans le futur, pour effectuer des opérations de filtrage sur vos données par exemple. Les types de données Python ont quelque chose de spécial.

# %%
x = "body mass index "
y = "this works too"
type(y)
# Out:
# str

# %%
qt = "0.75"
type(qt)
# Out:
# str

# %%
z = True
type(z)
# Out:
# bool

# %% [markdown]
# ###**8. Types Python (3)**
# + Regardez cette ligne de code, qui additionne deux entiers, puis cette ligne de code, qui additionne deux chaînes.
#
# + Pour les entiers, les valeurs ont été additionnées, tandis que pour les chaînes, les chaînes ont été collées ensemble.
#
# + L'opérateur plus s'est comporté différemment pour différents types de données.
#
# + C'est un principe général :
#   + le comportement du code dépend des types avec lesquels vous travaillez.
#
# + Dans les exercices qui suivent, vous allez créer vos premières variables et expérimenter avec certains des types de données de Python. Je vous verrai dans la prochaine vidéo pour vous expliquer tout sur les listes.

# %%
2+3
# Out:
# 5

# %%
w= 'ab' + 'cd'
w
# Out:
# 'abcd'

# %% [markdown]
# ###**9. Entraînons-nous !**
# + Laissez-vous coder et j'ai hâte de vous voir dans le prochain chapitre où vous construirez des graphiques en python encore plus impressionnants.

# %% [markdown]
# ###**Exercice**
#
# ####**Affectation variable**
#
# + En Python, une variable vous permet de faire référence à une valeur avec un nom. Pour créer une variable, utilisez =, comme dans cet exemple :
#
#       x = 5
#
# + Vous pouvez maintenant utiliser le nom de cette variable, x, au lieu de la valeur réelle, 5.
#
# + Rappelez-vous, **= en Python signifie affectation** , il ne teste pas l'égalité !
#
# ####**Des instructions**
#
#   + Créez une variable savingsavec la valeur 100.
#   + Vérifiez cette variable en tapant print(savings)dans le script.

# %%
# Create a variable savings
savings=100

# Print out savings
print(savings)
# Out:
# 100

# %% [markdown]
# ####**Calculs avec des variables**
#
# + Rappelez-vous comment vous avez calculé l'argent que vous avez obtenu après 7 ans d'investissement de 100 $ ? Vous avez fait quelque chose comme ça :
#
#       100 * 1.1 ** 7
#
# + Au lieu de calculer avec les valeurs réelles, vous pouvez utiliser des variables à la place.
# + La variable  savings que vous avez créée dans l'exercice précédent représente les 100 $ avec lesquels vous avez commencé.
# + A vous de créer une nouvelle variable à représenter 1.1puis de refaire les calculs !
#
# ####**Des instructions**
#
# + Créez une variable growth_multiplier, égale à 1.1.
# + Créez une variable, result, égale au montant d'argent que vous avez économisé après des 7 années.
# + Imprimez la valeur de result.

# %%
# Create a variable savings
savings = 100

# Create a variable growth_multiplier
growth_multiplier=1.1

year = 7
# Calculate result

result=savings*growth_multiplier**year
# Print out result
print(result)
# Out:
# 194.87171000000012

# %% [markdown]
# ###**Autres types de variables**
# + Dans l'exercice précédent, vous avez travaillé avec deux types de données Python :
#
#   + **int, ou entier** : un nombre sans partie fractionnaire.
#     + savings, avec la valeur 100, est un exemple d'entier.
#
#   + **float, ou virgule flottante**: un nombre qui a à la fois une partie entière et une partie fractionnaire, séparées par un point.
#     + growth_multiplier, avec la valeur 1.1, est un exemple de flotteur.
#
#
# + Outre les types de données numériques, il existe deux autres types de données très courants :
#
#   + **str, ou string**: un type pour représenter du texte. Vous pouvez utiliser des guillemets simples ou doubles pour créer une chaîne.
#
#   + **bool, ou booléen** : un type pour représenter des valeurs logiques. Ne peut être que Trueou False(la capitalisation est importante !).
#
# ####**Des instructions**
#
# + Créez une nouvelle chaîne, desc, avec la valeur "compound interest".
# + Créez un nouveau booléen, profitable, avec la valeur True.

# %%
# Create a variable desc
desc=str("compound interest")

# Create a variable profitable
profitable=True

# %% [markdown]
# ####**Devinez le type**
# + Pour connaître le type d'une valeur ou d'une variable qui fait référence à cette valeur, vous pouvez utiliser la fonction type().
#
# + Supposons que vous ayez défini une variable a, mais que vous ayez oublié le type de cette variable.
#
# + Pour déterminer le type de a, exécutez simplement :
#
#     type(a)
#
# + Nous sommes déjà allés de l'avant et avons créé trois variables : a, b et c.
#
# + Vous pouvez utiliser le shell IPython pour découvrir leur type. Laquelle des options suivantes est correcte ?
#
# **Des instructions**
#
# **Des réponses possibles**
#
# a est de type int, best de type str, cest de type bool
#
# a est de type float, best de type bool, cest de type str
#
# + **a est de type float, best de type str, cest de type bool**
#
# a est de type int, best de type bool, cest de type str

# %% [markdown]
# ###**Opérations avec d'autres types**
# + Hugo a mentionné que différents types se comportent différemment en Python.
#
# + Lorsque vous additionnez deux chaînes, par exemple, vous obtenez un comportement différent de celui obtenu lorsque vous additionnez deux entiers ou deux booléens.
#
# + Dans le script, certaines variables de différents types ont déjà été créées. C'est à vous de les utiliser.
#
# **Des instructions**
#
# + Calculer le produit de savingset growth_multiplier. Enregistrez le résultat dans year1.
# + Selon vous, quel sera le type résultant ? Découvrez-le en imprimant le type de year1.
# + Calculez la somme de descet descet stockez le résultat dans une nouvelle variable doubledesc.
# + Imprimez doubledesc. Vous attendiez-vous à cela ?

# %%
savings = 100
growth_multiplier = 1.1
desc = "compound interest"

# Assign product of growth_multiplier and savings to year1
year1=savings*growth_multiplier

# Print the type of year1

print(type(year1))
# Assign sum of desc and desc to doubledesc
doubledesc=desc+desc

# Print out doubledesc
print(doubledesc)

# %% [markdown]
# ###**Conversion de types**
# + L'utilisation de l' opérateur **+** pour coller ensemble deux chaînes peut être très utile pour créer des messages personnalisés.
#
# + Supposons, par exemple, que vous ayez calculé le retour de votre investissement et que vous souhaitiez résumer les résultats dans une chaîne.
#
# + En supposant que l'entier savingset le flottant resultsoient définis, vous pouvez essayer quelque chose comme ceci :
#
#       print("I started with $" + savings + " and now have $" + result + ". Awesome!")
#
# + Cela ne fonctionnera pas, cependant, car vous ne pouvez pas simplement additionner des chaînes et des entiers/flottants.
#
# + Pour corriger l'erreur, vous devrez convertir explicitement les types de vos variables. Plus précisément, vous aurez besoin str()de , pour convertir une valeur en chaîne. str(savings), par exemple, convertira l'entier savingsen chaîne.
#
# + Des fonctions similaires telles que **int(), float() et bool()** vous aideront à convertir les valeurs Python en n'importe quel type.
#
# ###**Des instructions**
#
# + Appuyez sur Exécuter le code pour exécuter le code. Essayez de comprendre le message d'erreur.
# + Corrigez le code de sorte que l'impression s'exécute sans erreur ; utilisez la fonction str() pour convertir les variables en chaînes.
# + Convertissez la variable pi_stringe n flottant et stockez ce flottant en tant que nouvelle variable, pi_float.

# %%
# Definition of savings and result
savings = 100
result = 100 * 1.10 ** 7

# Fix the printout
print("J'ai commencé mon investissement avec $" + str(savings) + " et maintenant j'ai $" + str(result) + ". Awesome!")

# Definition of pi_string
#pi_string = "3.1415926"

# Convert pi_string into float: pi_float
#pi_float = float(pi_string)
# Out:
# J'ai commencé mon investissement avec $100 et maintenant j'ai $194.87171000000012. Awesome!

# %% [markdown]
# ###**Python peut-il tout gérer ?**
#
# + Maintenant que vous en savez plus sur la combinaison de différentes sources d'informations, jetez un œil aux quatre expressions Python ci-dessous.
#
# + Lequel d'entre eux générera une erreur ? Vous pouvez toujours copier et coller ce code dans le shell IPython pour le savoir !
#
# **Des instructions**
#
# **Des réponses possibles**
#
# + "I can add integers, like " + str(5) + " to strings."
#
# + "I said " + ("Hey " * 2) + "Hey!"
#
# + "The correct answer to this multiple choice exercise is answer number " + 2
#
# + True + False

# %%
Listes Python
100 %
Apprenez à stocker, accéder et manipuler des données dans des listes : la première étape pour travailler efficacement avec d'énormes quantités de données.

Listes Python
50 XP
Créer une liste
70 XP
Créer une liste avec différents types
0 XP
Sélectionnez la liste valide
50 XP
Liste des listes
70 XP
Listes de sous-ensembles
50 XP
Sous-ensemble et conquérir
100 XP
Sous-ensemble et calcul
0 XP
Trancher et couper en dés
100 XP
Tranchage et dés (2)
100 XP
Sous-ensemble de listes de listes
50 XP
Manipuler des listes
50 XP
Remplacer les éléments de la liste
100 XP
Étendre une liste
100 XP
Supprimer des éléments de la liste
50 XP
Fonctionnement interne des listes

# %% [markdown]
# #**Listes Python**
#
# ####**1). Listes Python**
#
# + Bienvenue à nouveau Pythonista en herbe.
#
# + À ce jour, vous avez joué avec différents types de données, et j'espère que vous vous êtes autant amusé que moi.
#
# ####**2). Types de données Python**
#
# + Du côté des nombres, il y a le **float, pour représenter un nombre réel**, et **l'int, pour représenter un entier**.
#
# + Ensuite, nous avons également **str, abréviation de string, pour représenter le texte en Python**, et **bool, qui peut être True ou False**.
#
# + Vous pouvez enregistrer ces valeurs en tant que variable, comme le montrent ces exemples. Chaque variable représente alors une valeur unique.
#
# ####**3). Problème**
#
# + vous souhaiterez souvent travailler avec de nombreux points de données. + Si, par exemple, vous souhaitez mesurer la taille de tous les membres de votre famille et stocker ces informations dans Python, il serait peu pratique de créer une nouvelle variable Python pour chaque point que vous avez collecté, n'est-ce pas ? Ce que vous pouvez faire à la place, c'est stocker toutes ces informations dans une liste Python.

# %% [markdown]
# **Python Data Types**
# + float : real numbers
# + int : integer nubers
# + str : string, text
# + bool : True ou False

# %%
height = 1.73
tall = True
height1 = 1.73
height2 = 1.68
height3 = 1.71
height4 = 1.89

# %% [markdown]
# ####**4). Liste Python**
# + Vous pouvez construire une telle liste avec des crochets. Supposons que vous demandiez à vos deux sœurs et parents leur taille, en mètres.
#
# + Vous pouvez construire la liste comme suit :
#   + Bien sûr, cette structure de données peut également être référencée avec une variable.
#   + Mettez simplement le nom de la variable et le signe égal devant, comme ici.
#
# + **Une liste est un moyen de donner un nom unique à une collection de valeurs**.
#
# + Ces valeurs, ou éléments, peuvent avoir n'importe quel type ; ils peuvent être des flottants, des entiers, des booléens, des chaînes, mais aussi des types Python plus avancés, voire des listes.
#
# + Il est parfaitement possible qu'une liste contienne également différents types.

# %%
# Python List
fam = [1.73, 1.68, 1.71, 1.89]
fam
# Out:
# [1.73, 1.68, 1.71, 1.89]

# %%
type(fam)
# Out:
# list

# %% [markdown]
# ####**5. Liste Python**
#
# + Supposons, par exemple, que vous souhaitiez ajouter les noms de vos sœurs et de vos parents à la liste, afin de savoir quelle taille appartient à qui.
#
# + Vous pouvez jeter quelques chaînes sans problèmes. Mais ce n'est pas tout. Je viens de vous dire que les listes peuvent aussi contenir des listes elles-mêmes.
#
# + Au lieu de mettre les chaînes entre les chiffres, vous pouvez créer de petites sous-listes pour chaque membre de la famille. Un pour Liz, un pour Emma et ainsi de suite.
#
# + Maintenant, vous pouvez dire à Python que ces sous-listes sont les éléments d'une autre liste, que j'ai nommée fam2 :
#   + les petites listes sont entourées de crochets et séparées par des virgules.
#
#   + Si vous imprimez maintenant fam2, vous voyez que nous avons une liste de listes. La liste principale contient 4 sous-listes.
#
# + Nous avons affaire ici à un nouveau type Python, à côté des chaînes, des booléens, des entiers et des flottants que vous connaissez déjà :

# %%
fam = ["liz", 1.73, "emma", 1.68, "non", 1.71, "dad", 1.89]
fam
# Out:
# ['liz', 1.73, 'emma', 1.68, 'non', 1.71, 'dad', 1.89]

# %%
type(fam)
# Out:
# list

# %% [markdown]
# ###**6. Type de liste**
# + **la liste**.
# + Ces appels montrent que fam et fam2 sont des listes.
#
# +  Rappelez-vous que je vous ai dit que chaque type a des fonctionnalités et un comportement spécifiques associés ?
#
# + Eh bien, pour les listes, c'est également vrai. Les listes Python hébergent un tas d'outils pour les sous-ensembles et les adapter. Mais allons-y étape par étape,

# %%
fam2 = [["liz", 1.73],
        ["emma", 1.68],
        ["non", 1.68],
        ["dad", 1.89]]
fam2
# Out:
# [['liz', 1.73], ['emma', 1.68], ['non', 1.68], ['dad', 1.89]]

# %%
type(fam2)
# Out:
# list

# %% [markdown]
# ###**7. Entraînons-nous !**
# + et faites-vous d'abord expérimenter la création de listes !

# %% [markdown]
# #**Exercice**
#
# ####**Créer une liste**
# + Contrairement à int, booletc., une liste est un type de données composé ; vous pouvez regrouper des valeurs :
#
#       a = "is"
#       b = "nice"
#       my_list = ["my", "list", a, b]
#
# + Après avoir mesuré la taille de votre famille, vous décidez de collecter des informations sur la maison dans laquelle vous vivez.
#
# + Les zones des différentes parties de votre maison sont stockées dans des variables séparées pour le moment, comme indiqué dans le script.
#
# ####**Des instructions**
#
# + Créez une liste, areas, contenant la superficie du couloir ( hall), de la cuisine ( kit), du salon ( liv), de la chambre ( bed) et de la salle de bain ( bath), dans cet ordre.
#
# + Utilisez les variables prédéfinies.
# + Imprimer areas avec la fonction print().

# %%
# area variables (in square meters)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# Create list areas
areas=[hall,kit,liv,bed,bath]
# Print areas
print(areas)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]

# %% [markdown]
# ####**Créer une liste avec différents types**
#
# + Une liste peut contenir n'importe quel type Python. Bien que ce ne soit pas très courant, une liste peut également contenir un mélange de types Python, notamment des chaînes, des flottants, des booléens, etc.
#
# + L'impression de l'exercice précédent n'était pas vraiment satisfaisante. C'est juste une liste de nombres représentant les zones, mais vous ne pouvez pas dire quelle zone correspond à quelle partie de votre maison.
#
# + Le code dans l'éditeur est le début d'une solution. Pour certaines zones, le nom de la pièce correspondante est déjà placé devant. Faites attention ici! "bathroom"est une chaîne, tandis que bathest une variable qui représente le flottant 9.50 que vous avez spécifié précédemment.
#
# ####**Des instructions**
#
# + Terminez le code qui crée la areasliste. Construisez la liste de sorte que la liste contienne d'abord le nom de chaque pièce sous forme de chaîne, puis sa superficie.
#
# + En d'autres termes, ajoutez les chaînes "hallway", "kitchen"et "bedroom"aux emplacements appropriés.
#
# + Imprimez areasà nouveau ; l'impression est-elle plus informative cette fois ?

# %%
# area variables (in square meters)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# Adapt list areas
areas = ["hallway", hall, "kitchen", kit, "living room", liv, "bedroom", bed, "bathroom", bath]

# Print areas
print(areas)
# Out:
# ['hallway', 11.25, 'kitchen', 18.0, 'living room', 20.0, 'bedroom', 10.75, 'bathroom', 9.5]

# %% [markdown]
# ###**Sélectionnez la liste valide**
# + Une liste peut contenir n'importe quel type Python. Mais une liste elle-même est aussi un type Python.
#
# + Cela signifie qu'une liste peut aussi contenir une liste ! Python devient de plus en plus génial de minute en minute, mais n'ayez crainte, souvenez-vous simplement de la syntaxe de la liste :
#
#       my_list = [el1, el2, el3]
# + Pouvez-vous dire lesquelles des lignes de code Python suivantes sont des moyens valides de créer une liste ?
#
#       A.B.C. [1, 3, 4, 2] _ [[1, 2, 3], [4, 5, 7]] _[1 + 2, "a" * 5, 3]
#
# ####**Des instructions**
#
# ####**Des réponses possibles**
#
# + A, B et C (Vrai)
#
# + B
#
# + B et C
#
# + C

# %% [markdown]
# ####**Liste des listes**
# + En tant que data scientist, vous aurez souvent affaire à beaucoup de données, et il sera judicieux de regrouper certaines de ces données.
#
# + Au lieu de créer une liste plate contenant des chaînes et des flottants, représentant les noms et les zones des pièces de votre maison, vous pouvez créer une liste de listes. Le script dans l'éditeur peut déjà vous donner une idée.
#
# + Ne vous y trompez pas : "hallway" est une chaîne, tandis que hall est une variable qui représente le flottant 11.25 que vous avez spécifié précédemment.
#
# ####**Des instructions**
#
# + Terminez la liste des listes afin qu'elle contienne également les données de la chambre et de la salle de bain. Assurez-vous de les saisir dans l'ordre !
# + Imprimer house; cette façon de structurer vos données a-t-elle plus de sens ?
# + Imprimez le type de house. Avez-vous toujours affaire à une liste?

# %%
# area variables (in square meters)
hall = 11.25
kit = 18.0
liv = 20.0
bed = 10.75
bath = 9.50

# house information as list of lists
house = [["hallway", hall],
         ["kitchen", kit],
         ["living room", liv],
         ["bedroom",bed],
         ["bathroom",bath]]


# Print out house
print(house)
# Print out the type of house
print(type(house))
# Out:
# [['hallway', 11.25], ['kitchen', 18.0], ['living room', 20.0], ['bedroom', 10.75], ['bathroom', 9.5]]
# <class 'list'>

# %% [markdown]
# #**Listes de sous-ensembles**
#
# ####**1. Listes de sous-ensembles**
# + Après avoir créé votre propre liste Python, vous devez savoir comment accéder aux informations de la liste.
#
# ####**2. Listes de sous-ensembles**
# + Python utilise l'index pour ce faire. Jetez un coup d'œil à la liste des familles à nouveau ici.
#
# + Le premier élément de la liste a l'index 0, le deuxième élément a l'index 1, et ainsi de suite.
#
# + Supposons que vous souhaitiez sélectionner la hauteur d'emma, le flotteur 1.68. C'est le quatrième élément, il a donc l'indice 3.
#
# + Pour le sélectionner, vous utilisez 3 crochets à l'intérieur. De même, pour sélectionner la chaîne "papa" dans la liste,

# %% [markdown]
# **Subsetting lists**

# %%
fam = ["liz", 1.73, "emma", 1.68, "non", 1.71, "dad", 1.89]

# %%
fam[-2]
# Out:
# 'dad'

# %% [markdown]
# ####**3. Listes de sous-ensembles**
# + qui est le septième élément de la liste, vous devrez mettre l'index 6 entre crochets.
#
# + Vous pouvez également compter à rebours en utilisant des index négatifs. Ceci est utile si vous souhaitez obtenir des éléments à la fin de votre liste.
#
# + Pour obtenir la taille de votre père, par exemple, vous aurez besoin de l'indice -1. Ce sont les index négatifs pour tous les éléments de la liste.
#
# ####**4. Listes de sous-ensembles**
# + Cela signifie que ces deux lignes renvoient exactement le même résultat.
#
# + En plus de l'indexation, il existe également ce qu'on appelle le **découpage en tranches**,

# %%
fam = ["liz", 1.73, "emma", 1.68, "non", 1.71, "dad", 1.89]

# %%
fam[6]
# Out:
# 'dad'

# %%
fam[-2]
# Out:
# 'dad'

# %%
fam[7]

# %% [markdown]
# ####**5. Découpage de liste**
# + qui vous permet de sélectionner plusieurs éléments dans une liste, créant ainsi une nouvelle liste.
#
# + Vous pouvez le faire en spécifiant une plage, en utilisant deux-points. Jetons d'abord un autre coup d'œil à la liste, puis essayons ce morceau de code.
#
# + Pouvez-vous deviner ce qu'il va retourner? Une liste avec le flottant 1-point-68, la chaîne "mom", et le flottant 1-point-71, correspondant au 4ème, 5ème et 6ème élément de la liste peut-être ? Voyons quelle est la sortie.
#
# + Apparemment, seuls les éléments avec les index 3 et 4 sont renvoyés. L'élément d'indice 5 n'est pas inclus.
#
# + En général, c'est la syntaxe : l'index que vous spécifiez avant les deux-points, donc où la tranche commence, est inclus, tandis que l'index que vous spécifiez après les deux-points, où la tranche se termine, ne l'est pas.
#
# + Avec ça en tête, pouvez-vous dire ce que cet appel renverra ?
#
# + Vous avez probablement deviné correctement que cet appel vous donne une liste de trois éléments, correspondant aux éléments d'index 1, 2 et 3 de la fam list.
#
# + Vous pouvez également choisir de simplement omettre l'index avant ou après les deux-points.
#
# ####**6. Découpage de liste**
# + Si vous omettez l'index où la tranche doit commencer, vous dites à Python de commencer la tranche à partir de l'index 0, comme dans cet exemple.
#
# + Si vous omettez l'index où la tranche doit se terminer, vous incluez tous les éléments jusqu'au dernier élément inclus de la liste, comme ici.

# %% [markdown]
# ***List Slicing***

# %%
fam
# Out:
# ['liz', 1.73, 'emma', 1.68, 'non', 1.71, 'dad', 1.89]

# %%
fam[3:5]
# Out:
# [1.68, 'non']

# %%
fam[1:4]
# Out:
# [1.73, 'emma', 1.68]

# %%
fam[:4]
# Out:
# ['liz', 1.73, 'emma', 1.68]

# %%
fam[5:]
# Out:
# [1.71, 'dad', 1.89]

# %% [markdown]
# ####**7. Entraînons-nous !**
#
# + Il est maintenant temps de passer aux exercices, où vous continuerez à travailler sur la liste que vous avez créée vous-même auparavant.
#
# + Vous utiliserez différentes méthodes de sous-ensemble pour obtenir exactement l'information dont vous avez besoin !

# %% [markdown]
# ###**Exercice**
#
# ####**Sous-ensemble et conquérir**
#
# + Créer des sous-ensembles de listes Python est un jeu d'enfant.
#
# + Prenez l'exemple de code ci-dessous, qui crée une liste x, puis sélectionne "b" à partir de celle-ci.
#
# + N'oubliez pas qu'il s'agit du deuxième élément, il a donc l'index 1. Vous pouvez également utiliser une indexation négative.
#
#       x = ["a", "b", "c", "d"]
#       x[1]
#       x[-3] # same result!
# + Vous souvenez-vous areasde la liste précédente, contenant à la fois des chaînes et des flottants ? Sa définition est déjà dans le script.
#
# + Pouvez-vous ajouter le code correct pour créer des sous-ensembles Python ?
#
# ####**Des instructions**
#
# + Imprimez le deuxième élément de la areas liste (il a la valeur 11.25).
# + Sous-ensemble et imprimez le dernier élément de areas, étant 9.50.
# + L'utilisation d'un indice négatif prend tout son sens ici !
# + Sélectionnez le nombre représentant la surface du salon ( 20.0) et imprimez-le.

# %%
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Print out second element from areas
print(areas[1])

# Print out last element from areas
print(areas[-1])

# Print out the area of the living room
print(areas[5])

# %% [markdown]
# ####**Sous-ensemble et calcul**
# + Après avoir extrait des valeurs d'une liste, vous pouvez les utiliser pour effectuer des calculs supplémentaires.
#
# + Prenons cet exemple, où le deuxième et le quatrième élément d'une liste x sont extraits.
#
# + Les chaînes qui en résultent sont collées ensemble à l'aide de l' +opérateur :
#
#       x = ["a", "b", "c", "d"]
#       print(x[1] + x[3])
#
# ####**Des instructions**
#
# + En utilisant une combinaison de sous-ensemble de liste et d'affectation de variable, créez une nouvelle variable, eat_sleep_area, qui contient la somme de la surface de la cuisine et de la surface de la chambre.
# Imprimer la nouvelle variable eat_sleep_area.

# %%
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Sum of kitchen and bedroom area: eat_sleep_area
eat_sleep_area = areas[3] + areas[-3]

# Print the variable eat_sleep_area
print(eat_sleep_area)

# %% [markdown]
# ####**Trancher et couper en dés**
# + La sélection de valeurs uniques dans une liste n'est qu'une partie de l'histoire. I
#
# + l est également possible de découper votre liste, ce qui signifie sélectionner plusieurs éléments dans votre liste. Utilisez la syntaxe suivante :
#
#       my_list[start:end]
#
# + L'index start sera inclus, alors que l'index end n'est pas .
#
# + L'exemple de code ci-dessous montre un exemple. Une liste avec "b"et "c", correspondant aux index 1 et 2, sont sélectionnés parmi une liste x:
#
#       x = ["a", "b", "c", "d"]
#       x[1:3]
#
# + Les éléments d'index 1 et 2 sont inclus, tandis que l'élément d'index 3 ne l'est pas.
#
#
# ####**Des instructions**
#
# + Utilisez le découpage en tranches pour créer une liste, downstairs, qui contient les 6 premiers éléments de areas.
# + Faites la même chose pour créer une nouvelle variable, upstairs, qui contient les 4 derniers éléments de areas.
# + Imprimez à la fois downstairset upstairs en utilisant print().

# %%
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Use slicing to create downstairs
downstairs=areas[0:6]

# Use slicing to create upstairs
upstairs=areas[6:10]

# Print out downstairs and upstairs
print(downstairs,upstairs)

# %% [markdown]
# ####**ranchage et dés (2)**
# + Dans la vidéo, Hugo a d'abord discuté de la syntaxe où vous spécifiez à la fois où commencer et terminer la tranche de votre liste :
#
#       my_list[begin:end]
#
# + Cependant, il est également possible de ne pas spécifier ces index.
#
# + Si vous ne spécifiez pas l' beginindex, Python comprend que vous voulez commencer votre tranche au début de votre liste.
#
# + Si vous ne spécifiez pas l' endindex, la tranche ira jusqu'au dernier élément de votre liste. Pour expérimenter cela, essayez les commandes suivantes dans le shell IPython :
#
#       x = ["a", "b", "c", "d"]
#       x[:2]
#       x[2:]
#       x[:]
# ####**Des instructions**
#
# + Créez à nouveaudownstairs , comme les premiers 6 éléments de areas.
# + Cette fois, simplifiez le découpage en omettant l'index begin.
# + Créez upstairs à nouveau, en tant que derniers 4 éléments de areas. + Cette fois, simplifiez le découpage en omettant l'index end.

# %%
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Alternative slicing to create downstairs
downstairs=areas[:6]
print(downstairs)
# Alternative slicing to create upstairs
upstairs=areas[6:]
print(upstairs)

# %% [markdown]
# ####**Sous-ensemble de listes de listes**
#
# + Vous avez vu précédemment qu'une liste Python peut contenir pratiquement n'importe quoi ; même d'autres listes ! Pour créer des sous-ensembles de listes de listes, vous pouvez utiliser la même technique qu'auparavant : les crochets.
#
# + Essayez les commandes dans l'exemple de code suivant dans le shell IPython :
#
#       x = [["a", "b", "c"],
#           ["d", "e", "f"],
#           ["g", "h", "i"]]
#       x[2][0]
#       x[2][:2]
#       x[2]
#
# + résultats dans une liste, que vous pouvez à nouveau sous-ensemble en ajoutant des crochets supplémentaires.
#
# + Qu'est-ce qui va revenir  house[-1][1]? house, la liste des listes que vous avez créées auparavant, est déjà définie pour vous dans l'espace de travail.
#
# + Vous pouvez l'expérimenter dans le shell IPython.
#
# ####**Des instructions**
#
# ####**Des réponses possibles**
#
# + Un flotteur : le coin cuisine
#
# + Un string:"kitchen"
#
# + **Un flotteur : le coin salle de bain**
#
# + Un string:"bathroom"

# %% [markdown]
# ###**Manipuler des listes**
#
# ####**1. Manipuler des listes**
#
# + Wow, tu vas super bien.
#
# + Alors maintenant, après la création et le sous-ensemble, la dernière pièce du puzzle des listes Python est
#
# ####**2. Manipulation de liste**
# + manipulation, donc des moyens de modifier des éléments dans votre liste, ou d'ajouter et de supprimer des éléments de votre liste.
#
# ####**3. Modification des éléments de la liste**
# + Changer les éléments de la liste est assez simple.
#
# + Vous utilisez les mêmes crochets que nous avons utilisés pour les listes de sous-ensembles, puis vous lui affectez de nouveaux éléments à l'aide du signe égal. Supposons qu'après un autre regard sur fam, vous vous rendiez compte que la taille de votre père n'est plus à jour, car il rétrécit avec l'âge.
#
# + Au lieu de 1 point 89 mètres, il devrait être 1 point 86 mètres. Pour modifier cet élément de liste, qui est à l'index 7, vous pouvez utiliser cette ligne de code.
#
# + Si vous consultez maintenant fam, vous verrez que la valeur est mise à jour.
#
# + Vous pouvez même modifier une tranche de liste entière à la fois.
#
# + Pour changer les éléments "liz" et 1-point-73, vous accédez aux deux premiers éléments avec 0:2, puis lui attribuez une nouvelle liste.
#
# + Vous souvenez-vous encore en quoi l'opérateur plus était différent pour les chaînes et les entiers ?

# %% [markdown]
# **Changing list elements**

# %%
fam
# Out:
# ['liz', 1.73, 'emma', 1.68, 'non', 1.71, 'dad', 1.89]

# %%
fam[7]
# Out:
# 1.89

# %%
fam[7]=1.86
fam
# Out:
# ['liz', 1.73, 'emma', 1.68, 'non', 1.71, 'dad', 1.86]

# %%
fam[0:2] = ['lisa', 1.74]
fam
# Out:
# ['lisa', 1.74, 'emma', 1.68, 'non', 1.71, 'dad', 1.86]

# %% [markdown]
# ####**4. Ajout et suppression d'éléments**
#
# + Eh bien, c'est encore différent pour les listes. Si vous utilisez le signe plus avec deux listes, Python colle simplement leur contenu dans une seule liste.
#
# + Supposons que vous vouliez ajouter votre propre nom et taille à la liste des hauteurs fam.
#
# + Ça fera l'affaire. Bien entendu, vous pouvez également stocker cette nouvelle liste dans une variable, fam_ext par exemple.
#
# + Enfin, la suppression d'éléments d'une liste est également assez simple, vous devrez utiliser del ici. Prenez cette ligne, par exemple, qui supprime l'élément avec l'index 2, donc "emma", de la liste.
#
# + Si vous consultez fam maintenant, vous verrez que la chaîne "emma" a disparu.
#
# + Parce que vous avez supprimé un index, tous les éléments qui venaient après "emma" ont été déplacés par un index.
#
# + Si vous exécutez à nouveau la même ligne, vous supprimez à nouveau l'élément à l'index 2, qui est la hauteur d'Emma, ​​1 point 68 mètres maintenant.

# %% [markdown]
# **Adding and removing elements**

# %%
fam + ["me", 1.79]
# Out:
# ['lisa', 1.74, 'non', 1.71, 'dad', 1.86, 'me', 1.79]

# %%
fam_ext = fam + ["me", 1.79]
del(fam[2])
fam
# Out:
# ['lisa', 1.74, 'non', 1.71, 'dad', 1.86]

# %%
del(fam[0])
fam
# Out:
# [1.74, 'non', 1.71, 'dad', 1.86]

# %% [markdown]
# ####**5. Dans les coulisses (1)**
# dans les coulisses devient assez important maintenant.
#
# + Que se passe-t-il réellement lorsque vous créez une nouvelle liste, x, comme celle-ci ? Eh bien, dans un sens simplifié, vous stockez une liste dans la mémoire de votre ordinateur et stockez "l'adresse" de cette liste, donc
#
#
# ####**6. Dans les coulisses (1)**
# où se trouve la liste dans la mémoire de votre ordinateur, en x.
#
# + Cela signifie que x ne contient pas réellement tous les éléments de la liste, il contient plutôt une référence à la liste.
#
# + Pour les opérations de base, la différence n'est pas si importante, mais elle le devient davantage lorsque vous commencez à copier des listes.
#
# + Permettez-moi de clarifier cela avec un exemple.
#
# + Stockons la liste x comme une nouvelle variable y, en utilisant simplement le signe égal.
#
# + Changeons maintenant l'élément d'index un dans la liste y, comme ceci.
#
# + La chose géniale est que si vous vérifiez à nouveau x, ici aussi le deuxième élément a été modifié.
#
# + C'est parce que lorsque vous avez copié x sur y avec le signe égal,
#
# ####**7. Dans les coulisses (1)**
#
# + vous avez copié la référence à la liste, pas les valeurs réelles elles-mêmes.
#
# ####**8. Dans les coulisses (1)**
#
# + Lorsque vous mettez à jour un élément de la liste, c'est une seule et même liste dans la mémoire de l'ordinateur que vous modifiez.
#
# + x et y pointent vers cette liste, de sorte que la mise à jour est visible à partir des deux variables.
#
# + Si vous voulez créer une liste y qui pointe vers une nouvelle liste en mémoire avec les mêmes valeurs,

# %% [markdown]
# **Behind Scene**

# %%
x = ["a", "b", "c"]
y=x
y[1]="z"
y
# Out:
# ['a', 'z', 'c']

# %%
x
# Out:
# ['a', 'z', 'c']

# %% [markdown]
# ####**9. Dans les coulisses (2)**
#
# + vous devrez utiliser autre chose que le signe égal. Vous pouvez utiliser la fonction de liste,
#
# ####**10. Dans les coulisses (2)**
#
# + comme ceci, ou utilisez le découpage pour sélectionner explicitement tous les éléments de la liste. Si vous maintenant
#
# ####**11. Dans les coulisses (2)**
# modifier la liste vers laquelle pointe y, x n'est pas affecté.
#
# + Si c'était un peu trop à encaisser, ne vous inquiétez pas.

# %%
x = ["a", "b", "c"]
y=list(x)
y=x[:]
y[1]="z"
y
# Out:
# ['a', 'z', 'c']

# %%
x
# Out:
# ['a', 'b', 'c']

# %% [markdown]
# ####**12. Entraînons-nous !**
# + Les exercices vous aideront à comprendre la manipulation des listes et le fonctionnement interne subtil des listes.
#
# + Je suis sûr que tu iras très bien !

# %% [markdown]
# ###**Exercice**
#
# ####**Remplacer les éléments de la liste**
#
# + Remplacer les éléments de la liste est assez facile.
#
# + Créez simplement un sous-ensemble de la liste et attribuez de nouvelles valeurs au sous-ensemble.
#
# + Vous pouvez sélectionner des éléments uniques ou vous pouvez modifier des tranches de liste entières à la fois.
#
# + Utilisez le shell IPython pour expérimenter les commandes ci-dessous. + Pouvez-vous dire ce qui se passe et pourquoi ?
#
#       x = ["a", "b", "c", "d"]
#       x[1] = "r"
#       x[2:] = ["s", "t"]
#
# + Pour cet exercice et les suivants, vous continuerez à travailler sur la areasliste qui contient les noms et les zones des différentes pièces d'une maison.
#
# ####**Des instructions**
#
# + Mettez à jour la superficie de la salle de bain pour qu'elle soit de 10,50 mètres carrés au lieu de 9,50.
# + Rendez la areasliste plus tendance ! Passez "living room"à "chill zone".

# %%
# Create the areas list
areas = ["hallway", 11.25, "kitchen", 18.0, "living room", 20.0, "bedroom", 10.75, "bathroom", 9.50]

# Correct the bathroom area
areas[-1]=10.50
print(areas)
# Change "living room" to "chill zone"
areas[4]="chill zone"
print(areas)

# %% [markdown]
# ####**Étendre une liste**
#
# + Si vous pouvez modifier des éléments dans une liste, vous voulez certainement pouvoir y ajouter des éléments, n'est-ce pas ?
#
# + Vous pouvez utiliser l'opérateur +:
#
#       x = ["a", "b", "c", "d"]
#       y = x + ["e", "f"]
# + Vous venez de gagner à la loterie, génial ! Vous décidez de construire un poolhouse et un garage.
#
# + Pouvez-vous ajouter les informations à la areasliste ?
#
# ####**Instructions**
#
# + Utilisez l'opérateur + pour coller la liste ["poolhouse", 24.5]à la fin de la areasliste.
#
# + Enregistrez la liste résultante au format areas_1.
# + Prolongez encore areas_1en ajoutant des données sur votre garage.
# + Ajoutez la chaîne "garage"et float 15.45.
# + Nommez la liste résultante areas_2.

# %%
# Create the areas list and make some changes
areas = ["hallway", 11.25, "kitchen", 18.0, "chill zone", 20.0,
         "bedroom", 10.75, "bathroom", 10.50]

# Add poolhouse data to areas, new list is areas_1
areas_1=areas+["poolhouse",24.5]
print(areas_1)

# Add garage data to areas_1, new list is areas_2
areas_2=areas_1+["garage",15.45]
print(areas_2)

# %% [markdown]
# ####**Supprimer des éléments de la liste**
# + Enfin, vous pouvez également supprimer des éléments de votre liste. Vous pouvez le faire avec la deldéclaration :
#
#       x = ["a", "b", "c", "d"]
#       del(x[1])
#
# + Faites attention ici : dès que vous supprimez un élément d'une liste, les index des éléments qui viennent après l'élément supprimé changent tous !
#
# + La version mise à jour et étendue de areascelle que vous avez construite dans les exercices précédents est codée ci-dessous.
#
# + Vous pouvez copier et coller ceci dans le shell IPython pour jouer avec le résultat.
#
#       areas = ["hallway", 11.25, "kitchen", 18.0,
#               "chill zone", 20.0, "bedroom", 10.75,
#               "bathroom", 10.50, "poolhouse", 24.5,
#               "garage", 15.45]
#
# + Il y avait une erreur! Le montant que vous avez gagné à la loterie n'est pas si gros après tout et il semble que le poolhouse ne se produira pas.
#
#  + Vous décidez de supprimer la chaîne correspondante et de flotter dans la liste areas.
#
# + Le signe ; est utilisé pour placer des commandes sur la même ligne. Les deux morceaux de code suivants sont équivalents :
#
# + Same line
#
#       command1; command2
#
# + Separate lines
#
#       command1
#       command2
#
# + Lequel des morceaux de code fera le travail pour nous ?
#
# ####**Des instructions**
#
# ####**Des réponses possibles**
#
# + del(areas[10]); del(areas[11])
#
# + del(areas[10:11])
#
# + **del(areas[-4:-2])**
#
# + del(areas[-3]); del(areas[-4])

# %% [markdown]
# ####**Fonctionnement interne des listes**
#
# + À la fin de la vidéo, Hugo a expliqué comment les listes Python fonctionnent en coulisses.
#
# + Dans cet exercice, vous obtiendrez une expérience pratique avec cela.
#
# + Le code Python dans le script crée déjà une liste avec le nom areas et une copie nommée areas_copy.
#
# + Ensuite, le premier élément de la areas_copyliste est modifié et la liste areas est imprimée.
#
# + Si vous appuyez sur Exécuter le code , vous verrez que, bien que vous ayez modifié areas_copy, la modification prend également effet dans la areasliste.
#
# + C'est parce que areas et areas_copy pointent vers la même liste.
#
# + Si vous souhaitez empêcher les modifications areas_copy de prendre également effet dans areas, vous devrez faire une copie plus explicite de la liste areas.
#
# + Vous pouvez le faire avec list() ou en utilisant [:].
#
# ####**Des instructions**
#
# + Modifiez la deuxième commande, qui crée la variable areas_copy, de sorte qu'elle areas_copy soit une copie explicite de areas.
#
# + Après votre modification, les modifications apportées à areas_copy ne devraient pas affecter areas.
#
# + Soumettez la réponse pour vérifier cela.

# %%
# Create list areas
areas = [11.25, 18.0, 20.0, 10.75, 9.50]

# Create areas_copy
areas_copy = areas.copy()

# Change areas_copy
areas_copy[0] = 5.0

# Print areas
print(areas)

# %% [markdown]
# ####**Fonctions**
#
# ####**1. Fonctions**
#
# + Dans cette vidéo, je vais vous présenter les fonctions.
#
# + Une fois que vous les connaîtrez, vous ne pourrez plus arrêter de les utiliser.
#
# + Je ne peux certainement pas.
#
# ####**2. Fonctions**
#
# + Les fonctions ne sont pas entièrement nouvelles pour vous en fait : vous les avez déjà utilisées. type, par exemple, est une fonction qui renvoie le type d'une valeur. Mais qu'est-ce qu'une fonction ?
#
# + En termes simples, une fonction est un morceau de code réutilisable, destiné à résoudre une tâche particulière.
#
# + Vous pouvez appeler des fonctions au lieu d'avoir à écrire du code vous-même.
#
# + Peut-être qu'un exemple peut clarifier les choses ici.
#
# ####**3. Exemple**
#
# + Supposons que vous ayez la liste contenant uniquement les hauteurs de votre famille, fam :
#   + Supposons que vous souhaitiez obtenir la valeur maximale dans cette liste.
#
# + Au lieu d'écrire votre propre morceau de code Python qui parcourt la liste et trouve la valeur la plus élevée, vous pouvez également utiliser la fonction max de Python.
#
# + C'est l'une des fonctions intégrées de Python, tout comme type. Nous passons simplement fam à max entre parenthèses.
#
# + La sortie est logique : 1-point-89, le nombre le plus élevé de la liste.
#
# + max a fonctionné un peu comme une boîte noire ici :
#
# ####**4. Exemple**
#
# + vous lui avez passé une liste, puis l'implémentation de max, que vous ne connaissez pas, a fait sa magie,
#
# ####**5. Exemple**
#
# + et produit une sortie.
#
# + Comment max a réellement fait cela, n'est pas important pour vous, il fait juste ce qu'il est censé faire, et vous n'avez pas eu à écrire votre propre code, ce qui vous a facilité la vie.
#
# ####**6. Exemple**
#
# + Bien entendu, il est également possible d'affecter le résultat d'un appel de fonction à une nouvelle variable, comme ici. Maintenant, la plus grande est comme n'importe quelle autre variable ; vous pouvez l'utiliser pour continuer vos calculs fantaisistes.
#
# ####**7. rond()**
#
# + Une autre de ces fonctions intégrées est ronde.
#
# + Il faut deux entrées : premièrement, un nombre que vous souhaitez arrondir, et deuxièmement, la précision avec laquelle arrondir, c'est-à-dire le nombre de chiffres après la virgule décimale que vous souhaitez conserver.
#
# + Supposons que vous souhaitiez arrondir 1 point 68 à une décimale. La première entrée est 1-point-68, la deuxième entrée est 1.
#
# + Vous séparez les entrées par une virgule. Mais il y a plus. Il est parfaitement possible d'appeler la fonction round avec une seule entrée, comme ceci.
#
# + Cette fois, Python a compris que vous n'aviez pas spécifié la deuxième entrée et choisit automatiquement d'arrondir le nombre à l'entier le plus proche. Pour comprendre pourquoi les deux approches fonctionnent, ouvrons la documentation.
#
# + Vous pouvez le faire avec encore une autre fonction, help, comme celle-ci. Il semble que le tour prend deux entrées.
#
# ####**8. rond()**
#
# + En Python, ces entrées, aussi appelées arguments, ont des noms : number et ndigits. Lorsque vous appelez la fonction round,
#
# ####**9. rond()**
# + avec ces deux entrées, Python fait correspondre les entrées aux arguments :
#
# ####**10. rond()**
# + le nombre est fixé à 1-point-68 et
#
# ####**11. rond()**
# + ndigits est défini sur 1. Ensuite,
#
# ####**12. rond()**
#
# + La fonction round effectue ses calculs avec number et ndigits comme s'il s'agissait de variables Python dans un script.
#
# + Nous ne savons pas exactement quel code Python exécute.
#
# + Ce qui est important, cependant, c'est que la fonction produit une sortie,
#
# ####**13. rond()**
# + à savoir le nombre 1-point-68 arrondi à 1 décimale.
#
# ####**14. rond()**
# + i vous appelez la fonction round avec une seule entrée,
#
# ####**15. tour()**
# + Python essaie à nouveau de
#
# ####**6. tour()**
# + faire correspondre les entrées à
#
# ####**17. tour()**
# + les arguments. Il n'y a cependant aucune entrée à faire correspondre à l'argument ndigits. Heureusement,
#
# ####**18. tour()**
# + la machinerie interne de la fonction ronde sait comment gérer cela.
#
# + Lorsque ndigits n'est pas spécifié, la fonction arrondit simplement à l'entier le plus proche et
#
# ####**19. tour()**
# + renvoie cet entier. C'est pourquoi nous avons le numéro 2.
#
# ####**20. tour()**
# + En d'autres termes, ndigits est un argument facultatif.
#
# + Cela nous indique que vous pouvez appeler rond sous cette forme, ainsi que dans celle-ci.
#
# ####**21. Trouver des fonctions**
# + À présent, vous avez une idée sur la façon d'utiliser max et round, mais comment pourriez-vous savoir qu'une fonction telle que round existe en Python en premier lieu ?
#
# + Eh bien, c'est quelque chose que vous apprendrez avec le temps. Chaque fois que vous effectuez une tâche plutôt standard en Python, vous pouvez être sûr qu'il existe déjà une fonction qui peut le faire pour vous.
#
# + Dans ce cas, vous devez absolument l'utiliser ! Faites simplement une recherche rapide sur Internet et vous trouverez la fonction dont vous avez besoin avec un bel exemple d'utilisation.
#
# + Et il y a bien sûr DataCamp, où vous découvrirez également des fonctions puissantes et comment les utiliser.
#
# ####**22. Entraînons-nous !**
# + Allez-y directement dans les exercices interactifs, et je vous reverrai bientôt ici !

# %%
fam = [1.73, 1.68, 1.71, 1.89]
fam
# Out:
# [1.73, 1.68, 1.71, 1.89]

# %%
max(fam)
# Out:
# 1.89

# %%
tallest = max(fam)
tallest
# Out:
# 1.89

# %%
round(1.68,1)
# Out:
# 1.7

# %%
round(1.68)
# Out:
# 2

# %%
help(round)
# Out:
# Help on built-in function round in module builtins:
#
# round(number, ndigits=None)
#     Round a number to a given precision in decimal digits.
#
#     The return value is an integer if ndigits is omitted or None.  Otherwise
#     the return value has the same type as the number.  ndigits may be negative.

# %% [markdown]
# **Methods**
# + Maximum of list: max()
# + Length of list or string: len()
# + Get index in list: ?
# + Reversing a list: ?

# %% [markdown]
# ###**Exercice**
#
# ####**Fonctions familières**
#
# + Prêt à l'emploi, Python propose un ensemble de fonctions intégrées pour vous faciliter la vie en tant que data scientist.
#
# + Vous connaissez déjà deux de ces fonctions : **print()et type().**
#
# + Vous avez également utilisé les fonctions **str(), int()et bool()pour float()** basculer entre les types de données. Ce sont également des fonctions intégrées.
#
# + L'appel d'une fonction est facile. Pour obtenir le type de 3.0 et stocker la sortie en tant que nouvelle variable result, vous pouvez utiliser ce qui suit :
#
#       result = type(3.0)
# + La recette générale pour appeler des fonctions et enregistrer le résultat dans une variable est donc :
#
#       output = function_name(input)
#
# ####**Des instructions**
#
# + Utilisez print() en combinaison avec type() pour imprimer le type de var1.
# + Utilisez len() pour obtenir la longueur de la liste var1.
#
# + Enveloppez-le dans un appel print() pour l'imprimer directement.
#
# + Utiliser int() pour convertir var2 en entier. Stockez la sortie au format out2

# %%
# Create variables var1 and var2
var1 = [1, 2, 3, 4]
var2 = True

# Print out type of var1
print(type(var1))
print("************************")
# Print out length of var1
print(len(var1))
print("************************")
# Convert var2 to an integer: out2
out2=int(var2)
print(out2)
# Out:
# <class 'list'>
# ************************
# 4
# ************************
# 1

# %% [markdown]
# ####**ider!**
# + Peut-être connaissez-vous déjà le nom d'une fonction Python, mais vous devez encore savoir comment l'utiliser.
#
# + Ironie du sort, il faut demander des informations sur une fonction avec une autre fonction : **help()**.
#
# + Dans IPython en particulier, vous pouvez également utiliser ?avant le nom de la fonction.
#
# + Pour obtenir de l'aide sur la fonction max(), par exemple, vous pouvez utiliser l'un de ces appels :
#
#       help(max)
#       ?max
#
# + Utilisez le shell IPython pour ouvrir la documentation sur **pow()**. + Laquelle des affirmations suivantes est vraie?
#
# ####**Des instructions**
#
# ####**Des réponses possibles**
#
# + pow() prend trois arguments : base, exp, et mod. Si vous ne spécifiez pas mod, la fonction renverra une erreur.
#
# + pow() prend trois arguments : base, exp, et None. Tous ces arguments sont nécessaires.
#
# + **pow() prend trois arguments : base, exp, et mod. baseet expsont des arguments obligatoires, modest un argument facultatif.**
#
# + pow() prend deux arguments : expet mod. Si vous ne spécifiez pas exp, la fonction renverra une erreur.

# %% [markdown]
# ####**Arguments multiples**
#
# + Dans l'exercice précédent, vous avez identifié des arguments facultatifs en consultant la documentation avec **help()**.
#
# + Vous allez maintenant l'appliquer pour modifier le comportement de la fonction **sorted()**.
#
# + Jetez un œil à la documentation de **sorted()** en tapant **help(sorted)**dans le shell IPython.
#
# + Vous verrez que cela **sorted()** prend trois arguments :
#
#         iterable, key et reverse.
#
# + **key=None** signifie que si vous ne spécifiez pas l'argument key, ce sera None.
#
# + **reverse=Falses** ignifie que si vous ne spécifiez pas l' reverseargument, ce sera False, par défaut.
#
# + Dans cet exercice, vous n'aurez qu'à spécifier **iterable et reverse**, pas key.
#
# + La première entrée à laquelle vous passez sorted()sera associée à l' argument iterable  mais qu'en est-il de la deuxième entrée ?
#
# + Pour indiquer à Python que vous voulez spécifier reversesans rien changer à propos de key, vous pouvez utiliser = pour lui attribuer une nouvelle valeur :
#
#         sorted(____, reverse=____)
# + Deux listes ont été créées pour vous. Pouvez-vous les coller ensemble et les trier par ordre décroissant ?
#
# + **Remarque** : Pour l'instant, nous pouvons comprendre un itérable comme étant n'importe quelle collection d'objets, par exemple, une liste.
#
# ####**Des instructions**
#
# + Utilisez +pour fusionner le contenu de first et second dans une nouvelle liste : full.
# + Appelez et spécifiez l' argument à sorted()être . Enregistrez la liste triée sous .fullreverseTruefull_sorted
# + Terminez en imprimant full_sorted.

# %%
# Create lists first and second
first = [11.25, 18.0, 20.0]
second = [10.75, 9.50]

# Paste together first and second: full
full=first+second
print(full)
# Sort full in descending order: full_sorted
full_sorted=sorted(full,reverse=True)

# Print out full_sorted
print(full_sorted)
# Out:
# [11.25, 18.0, 20.0, 10.75, 9.5]
# [20.0, 18.0, 11.25, 10.75, 9.5]

# %% [markdown]
# 1. Méthodes
# Les fonctions intégrées sont uniquement
#
# 2. Fonctions intégrées
# une partie de l'histoire de Python. Vous connaissez déjà des fonctions telles que max, pour obtenir le maximum d'une liste, len, pour obtenir la longueur d'une liste ou d'une chaîne, etc. Mais qu'en est-il des autres choses de base, telles que l'obtention de l'index d'un élément spécifique dans la liste ou l'inversion d'une liste ? Vous pouvez rechercher très attentivement les fonctions intégrées qui font cela, mais vous ne les trouverez pas.
#
# 3. Retour 2 bases
# Dans les exercices précédents, vous avez déjà créé un tas de variables. Parmi les autres types Python, vous avez créé des chaînes, des flottants et des listes, comme ceux que vous voyez ici. Chacune de ces valeurs ou structures de données sont des objets dits Python. Cette chaîne est un objet, ce flottant est un objet, mais cette liste est aussi, vous l'avez compris, un objet. Ces objets ont un type spécifique, que vous connaissez déjà :
#
# 4. Retour 2 bases
# string, float et list, et bien sûr ils représentent les valeurs que vous leur avez données, telles que "liz", 1-point-73 et une liste entière. Mais en plus de cela, les objets Python sont également livrés avec un tas de soi-disant "méthodes". Vous pouvez considérer les méthodes comme des fonctions qui "appartiennent" aux objets Python. Un objet Python de type chaîne a des méthodes,
#
# 5. Retour 2 bases
# comme capitalize et replace, mais aussi les objets de type float et list ont des méthodes spécifiques selon le type. Assez pour la théorie maintenant; essayons d'utiliser une méthode !
#
# 6. lister les méthodes
# Supposons que vous souhaitiez obtenir l'index de la chaîne "mom" dans la liste fam. fam est un objet Python avec la liste de types et a une méthode nommée index. Pour appeler la méthode, vous utilisez la notation par points, comme ceci. La seule entrée est la chaîne "mom", l'élément pour lequel vous souhaitez obtenir l'index. Python renvoie 4, qui est bien l'index de la chaîne "mom". J'ai appelé la méthode d'index "sur" la liste fam ici, et le résultat était 4. De même, je peux utiliser la méthode count sur la liste fam pour compter le nombre de fois que 1-point-73 apparaît dans la liste. Python me donne 1, ce qui est logique, car seule Liz mesure 1 point 73 mètres. Mais les listes ne sont pas les seuls objets Python auxquels sont associées des méthodes. Également des flottants, des entiers, des booléens et des chaînes
#
# 7. méthodes str
# sont des objets Python auxquels sont associées des méthodes spécifiques. Prenez la variable sister par exemple, qui représente une chaîne. Vous pouvez appeler la méthode capitalize on sister, sans aucune entrée. Il renvoie une chaîne où la première lettre est maintenant en majuscule. Ou que se passe-t-il si vous souhaitez remplacer certaines parties de la corde par d'autres parties ? Pas de problème. Appelez simplement la méthode replace sur sister, avec deux entrées appropriées. Dans la sortie, "z" est remplacé par "sa".
#
# 8. Méthodes
# Pour être absolument clair : en Python, tout est un objet, et chaque objet est associé à des méthodes spécifiques. Selon le type d'objet, liste, chaîne, flottant, peu importe, les méthodes disponibles sont différentes. Un objet chaîne comme sister a une méthode replace, mais une liste comme fam ne l'a pas, comme vous pouvez le voir à partir de cette erreur.
#
# 9. Méthodes
# Des objets de types différents peuvent avoir des méthodes portant le même nom : Prenez la méthode index. Il est disponible pour les chaînes et les listes. Si vous l'appelez sur une chaîne, vous obtenez l'index des lettres de la chaîne ; Si vous l'appelez sur une liste, vous obtenez l'index de l'élément dans la liste. Cela signifie que, selon le type de l'objet, les méthodes se comportent différemment. Avant de vous lâcher sur quelques exercices sur les méthodes,
#
# 10. Méthodes (2)
# il y a encore une chose que je veux te dire. Certaines méthodes peuvent modifier les objets sur lesquels elles sont appelées. Reprenons la liste fam et appelons la méthode append dessus. En entrée, nous passons une chaîne que nous voulons ajouter à la liste. Python ne génère pas de sortie, mais si nous vérifions à nouveau la liste fam, nous voyons qu'elle a été étendue avec la chaîne "me". Recommençons, cette fois pour ajouter ma taille à la liste. Encore une fois, la liste des fam a été allongée. C'est plutôt cool, car vous pouvez écrire du code très concis pour mettre à jour vos structures de données à la volée, mais cela peut aussi être assez dangereux. Certains appels de méthode ne changent pas l'objet sur lequel ils sont appelés, tandis que d'autres le font, alors faites attention.
#
# 11. Résumé
# Prenons un peu de recul ici et résumons cela. vous avez des fonctions Python, comme type, max et round, que vous pouvez appeler comme ceci. Il existe également des méthodes, qui sont des fonctions spécifiques aux objets Python. Selon le type d'objet Python avec lequel vous traitez, vous pourrez utiliser différentes méthodes et elles se comporteront différemment. Vous pouvez appeler des méthodes sur les objets avec la notation par points, comme ceci, par exemple. Il y a beaucoup plus à dire sur les objets Python, les méthodes et le fonctionnement interne de Python,
#
# 12. Entraînons-nous !
# mais pour l'instant, restons-en à ce dont j'ai parlé ici. Il est temps de faire des exercices et d'ajouter des méthodes à vos compétences en constante évolution !

# %%
sister = "liz"

# %%
height = 1.73

# %%
fam = ["liz", 1.73, "emma", 1.68,"emma", 1.71,"dad", 1.89]
fam
# Out:
# ['liz', 1.73, 'emma', 1.68, 'emma', 1.71, 'dad', 1.89]

# %%
fam.index("emma")
# Out:
# 2

# %%
fam.count(1.73)
# Out:
# 1

# %%
sister
# Out:
# 'liz'

# %%
sister.capitalize()
# Out:
# 'Liz'

# %%
sister.replace("z", "sa")
# Out:
# 'lisa'

# %%
sister.index("z")
# Out:
# 2

# %%
fam.index("mom")
# Out:
# 4

# %%
fam
# Out:
# ['liz', 1.73, 'emma', 1.68, 'mom', 1.71, 'dad', 1.89]

# %%
fam.append("me")
fam
# Out:
# ['liz', 1.73, 'emma', 1.68, 'mom', 1.71, 'dad', 1.89, 'me']

# %% [markdown]
# **Summary**

# %%
type(fam)
# Out:
# list

# %%
fam.index("dad")
# Out:
# 6

# %% [markdown]
# **Import package**

# %%
import numpy
#array([1, 2,3])

# %%
import numpy as np
a=np.array([1, 2, 3])
a
# Out:
# array([1, 2, 3])

# %%
from numpy import array
fam = ["liz", 1.73,"emma", 1.68,"mom", 1.71,"dad", 1.89]
...
fam_ext = fam + ["me", 1.79]
...
print(str(len(fam_ext)) + " elements in fam_ext")
...
np_fam = array(fam_ext)
# Out:
# 10 elements in fam_ext

# %% [markdown]
# **Lists Recap**
# + Powerful
# + Collection of values
# + Hold different types
# + change, add, remove
# + Need for Data Science:
#   - Mathematical operations over     collections
#   - speed

# %% [markdown]
# **Illustration**

# %%
height = [1.73, 1.68, 1.71, 1.89, 1.79]
height
# Out:
# [1.73, 1.68, 1.71, 1.89, 1.79]

# %%
weight = [65.4, 59.2, 63.6, 88.4, 68.7]
weight
# Out:
# [65.4, 59.2, 63.6, 88.4, 68.7]

# %%
#weight / height ** 2

# %% [markdown]
# **Solution: Numpy**
# + Numeric Python
# + Alternative to Python List: Numpy Array
# + Calculations over entire arrays
# + Easy and Fast
# + Installation
#     - In the terminal: pip3 install numpy

# %% [markdown]
# **Numpy**

# %%
import numpy as np
np_height = np.array(height)
np_height
# Out:
# array([1.73, 1.68, 1.71, 1.89, 1.79])

# %%
np_weight = np.array(weight)
np_weight
# Out:
# array([65.4, 59.2, 63.6, 88.4, 68.7])

# %%
bmi = np_weight/(np_height ** 2)
bmi
# Out:
# array([21.85171573, 20.97505669, 21.75028214, 24.7473475 , 21.44127836])

# %% [markdown]
# **Comparaison**

# %%
import numpy as np

# %%
height = [1.73, 1.68, 1.71, 1.89, 1.79]
weight = [65.4, 59.2, 63.6, 88.4, 68.7]
#weight / height ** 2

# %%
np_height = np.array(height)
np_weight = np.array(weight)
np_weight / np_height ** 2
# Out:
# array([21.85171573, 20.97505669, 21.75028214, 24.7473475 , 21.44127836])

# %% [markdown]
# **Numpy: remarks**

# %%
np.array([1.0,"is", True])
# Out:
# array(['1.0', 'is', 'True'], dtype='<U32')

# %%
python_list = [1, 2, 3]
numpy_array = np.array([1, 2, 3])

# %%
python_list + numpy_array
# Out:
# array([2, 4, 6])

# %%
numpy_array + numpy_array
# Out:
# array([2, 4, 6])

# %% [markdown]
# **Numpy Subsetting**

# %%
bmi
# Out:
# array([21.85171573, 20.97505669, 21.75028214, 24.7473475 , 21.44127836])

# %%
bmi[1]
# Out:
# 20.97505668934241

# %%
bmi>23
# Out:
# array([False, False, False,  True, False])

# %%
bmi[bmi>23]
# Out:
# array([24.7473475])

# %% [markdown]
# **2D Numpy Arrays**

# %% [markdown]
# *Type of Numpy Arrays*

# %%
import numpy as np
np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])

# %%
type(np_height)
# Out:
# numpy.ndarray

# %%
type(np_weight)
# Out:
# numpy.ndarray

# %% [markdown]
# *2D Numpy Arrays*

# %%
np_2d = np.array([[1.73, 1.68, 1.71, 1.89, 1.79],[65.4, 59.2, 63.6, 88.4, 68.7]])
np_2d
# Out:
# array([[ 1.73,  1.68,  1.71,  1.89,  1.79],
#        [65.4 , 59.2 , 63.6 , 88.4 , 68.7 ]])

# %%
np_2d.shape
# Out:
# (2, 5)

# %%
np.array([[1.73, 1.68, 1.71, 1.89, 1.79],[65.4, 59.2, 63.6, 88.4,"68.7"]])
# Out:
# array([['1.73', '1.68', '1.71', '1.89', '1.79'],
#        ['65.4', '59.2', '63.6', '88.4', '68.7']], dtype='<U32')

# %% [markdown]
# *Subsetting*

# %%
np_2d[0]
# Out:
# array([1.73, 1.68, 1.71, 1.89, 1.79])

# %%
np_2d[0][2]
# Out:
# 1.71

# %%
np_2d[0,2]
# Out:
# 1.71

# %%
np_2d[:,1:3]
# Out:
# array([[ 1.68,  1.71],
#        [59.2 , 63.6 ]])

# %%
np_2d[1,:]
# Out:
# array([65.4, 59.2, 63.6, 88.4, 68.7])

# %% [markdown]
# **Numpy: Basic Statistics**

# %%
import pandas as pd
from pprint import pprint as pp
from itertools import combinations
from zipfile import ZipFile
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import numpy as np
from pathlib import Path
import requests
import sys

# %%
baseball= 'https://assets.datacamp.com/production/repositories/288/datasets/e5d60ff535f86d27609312f9e41c35a1d737ddc0/baseball.csv'
fifa='https://assets.datacamp.com/production/repositories/288/datasets/026a5211b906ac118a09b1a0dbf7df48faafb379/fifa.csv'
gapminder= 'https://assets.datacamp.com/production/repositories/287/datasets/5b1e4356f9fa5b5ce32e9bd2b75c777284819cca/gapminder.csv'
cars = 'https://assets.datacamp.com/production/repositories/287/datasets/79b3c22c47a2f45a800c62cae39035ff2ea4e609/cars.csv'
brics = 'https://assets.datacamp.com/production/repositories/287/datasets/b60fb5bdbeb4e4ab0545c485d351e6ff5428a155/brics.csv'

# %%
def create_dir_save_file(dir_path: Path, url: str):
    """
    Check if the path exists and create it if it does not.
    Check if the file exists and download it if it does not.
    """
    if not dir_path.parents[0].exists():
        dir_path.parents[0].mkdir(parents=True)
        print(f'Directory Created: {dir_path.parents[0]}')
    else:
        print('Directory Exists')

    if not dir_path.exists():
        r = requests.get(url, allow_redirects=True)
        open(dir_path, 'wb').write(r.content)
        print(f'File Created: {dir_path.name}')
    else:
        print('File Exists')

# %%
data_dir = Path('data/2021-03-29_intro-to-python-for-data-science/chapter-1-python-basics?')
images_dir = Path('Images/2021-03-29_intro-to-python-for-data-science/chapter-1-python-basics?')

# %%
file_links = [baseball, fifa, gapminder, cars, brics]
file_paths = list()

for file in file_links:
    file_name = file.split('/')[-1].replace('?raw=true', '').replace('%20', '_')
    data_path = data_dir / file_name
    create_dir_save_file(data_path, file)
    file_paths.append(data_path)
# Out:
# Directory Exists
# File Exists
# Directory Exists
# File Exists
# Directory Exists
# File Created: gapminder.csv
# Directory Exists
# File Created: cars.csv
# Directory Exists
# File Created: brics.csv

# %%
import pandas as pd

# %%
df = pd.read_csv(brics)
df.head(5)
# Out:
#   Unnamed: 0       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'country', 'capital', 'area', 'population'], dtype='object')

# %%
df_1 = pd.read_csv(cars)
df_1.head(5)
# Out:
#   Unnamed: 0  cars_per_cap        country  drives_right
# 0         US           809  United States          True
# 1        AUS           731      Australia         False
# 2        JAP           588          Japan         False
# 3         IN            18          India         False
# 4         RU           200         Russia          True

# %%
df_1.columns
# Out:
# Index(['Unnamed: 0', 'cars_per_cap', 'country', 'drives_right'], dtype='object')

# %%
df_2 = pd.read_csv(gapminder)
df_2.head(5)
# Out:
#    Unnamed: 0      country  year  population      cont  life_exp       gdp_cap
# 0          11  Afghanistan  2007  31889923.0      Asia    43.828    974.580338
# 1          23      Albania  2007   3600523.0    Europe    76.423   5937.029526
# 2          35      Algeria  2007  33333216.0    Africa    72.301   6223.367465
# 3          47       Angola  2007  12420476.0    Africa    42.731   4797.231267
# 4          59    Argentina  2007  40301927.0  Americas    75.320  12779.379640

# %%
df_2.columns
# Out:
# Index(['Unnamed: 0', 'country', 'year', 'population', 'cont', 'life_exp',
#        'gdp_cap'],
#       dtype='object')

# %%
np_city = np.array([[1.64, 71.78],
           [1.37, 63.35],
           [1.6, 55.09],
           [2.04, 74.85],
           [2.04, 68.72],
           [2.01, 73.57]])
np_city
# Out:
# array([[ 1.64, 71.78],
#        [ 1.37, 63.35],
#        [ 1.6 , 55.09],
#        [ 2.04, 74.85],
#        [ 2.04, 68.72],
#        [ 2.01, 73.57]])

# %%
np.mean(np_city[:,0])
# Out:
# 1.7833333333333332

# %%
np.median(np_city[:,0])
# Out:
# 1.8249999999999997

# %%
np.corrcoef(np_city[:,0], np_city[:,1])
# Out:
# array([[1.        , 0.64924262],
#        [0.64924262, 1.        ]])

# %%
np.std(np_city[:,0])
# Out:
# 0.2608107018935807

# %%
np.sum(np_city)
# Out:
# 418.06

# %%
np.sort(np_city)
# Out:
# array([[ 1.64, 71.78],
#        [ 1.37, 63.35],
#        [ 1.6 , 55.09],
#        [ 2.04, 74.85],
#        [ 2.04, 68.72],
#        [ 2.01, 73.57]])

# %% [markdown]
# **Generate data**
# + Arguments for **np.random.normal()**
# + distribution mean
# + distribution standard deviation
# + number of samples

# %%
height = np.round(np.random.normal(1.75, 0.20, 5000), 2)
weight = np.round(np.random.normal(60.32, 15, 5000), 2)

# %%
height
# Out:
# array([1.61, 1.93, 1.45, ..., 1.7 , 1.76, 1.57])

# %%
weight
# Out:
# array([47.52, 38.84, 48.48, ..., 42.83, 74.61, 71.57])

# %%
np_city = np.column_stack((height, weight))
np_city
# Out:
# array([[ 1.61, 47.52],
#        [ 1.93, 38.84],
#        [ 1.45, 48.48],
#        ...,
#        [ 1.7 , 42.83],
#        [ 1.76, 74.61],
#        [ 1.57, 71.57]])

# %% [markdown]
# # Introduction to Data Visualization with Matplotlib

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
plt.show()

# %% [markdown]
# **Adding data to axes**

# %%
df_1["cars_per_cap"]
# Out:
# 0    809
# 1    731
# 2    588
# 3     18
# 4    200
# 5     70
# 6     45
# Name: cars_per_cap, dtype: int64

# %%
df_1["country"]
# Out:
# 0    United States
# 1        Australia
# 2            Japan
# 3            India
# 4           Russia
# 5          Morocco
# 6            Egypt
# Name: country, dtype: object

# %% [markdown]
# **Adding data to axes**

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df_1["country"], df_1["cars_per_cap"])
plt.show()

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df["country"], df["population"])
plt.show()

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df_1["country"], df_1["cars_per_cap"])
ax.plot(df["country"], df["population"])
plt.show()

# %% [markdown]
# **Adding markers**

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df["country"],
        df["population"],
        marker="o")
plt.show()

# %% [markdown]
# **Choosing markers**

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df["country"],
        df["population"],
        marker="v")
plt.show()

# %% [markdown]
# **Setting the linestyle**

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df["country"],
        df["population"],
        marker="v", linestyle='--')
plt.show()

# %% [markdown]
# **Eliminating lines with linestyle**

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df["country"],
        df["population"],
        marker="v", linestyle="None")
plt.show()

# %% [markdown]
# **Choosing color**

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df["country"],
        df["population"],
        marker="v", linestyle="--", color="r")
ax.set_xlabel("country")        # setting the x axis label
ax.set_ylabel("population")     # setting the y label
plt.show()

# %% [markdown]
# **Adding more data**

# %%
fig, ax =plt.subplots(figsize=(16,8))
ax.plot(df["country"],
        df["population"],color="b")
ax.plot(df["country"],
        df["population"], linestyle="--", color="r")
ax.plot(df["country"],df["population"], linestyle="--", color="r")
ax.set_xlabel("country")        # setting the x axis label
ax.set_ylabel("population")     # setting the y label
plt.show()

# %% [markdown]
# **Small multiples with plt.subplots**

# %%
fig, ax = plt.subplots()

# %%
fig, ax = plt.subplots(3, 2)
plt.show()

# %% [markdown]
# **Adding data to subplots**

# %%
ax.shape
# Out:
# (3, 2)

# %%
fig, ax = plt.subplots(3, 2)
#fig, ax = plt.subplots(2, 1, sharey=True)
ax[0, 0].plot(df["country"],df["population"],color="b")
plt.show()

# %% [markdown]
# **Dictionaries**

# %% [markdown]
# **List**

# %%
pop = [30.55, 2.77, 39.21]
countries = ["afghanisatan", "albania", "algeria"]
ind_alb= countries.index("albania")
ind_alb
# Out:
# 1

# %%
pop[ind_alb]
# Out:
# 2.77

# %% [markdown]
# **Dictionary**

# %%
word={"afghanistan":30.55, "albania":2.77, "algeria":39.21}

# %%
word["albania"]
# Out:
# 2.77

# %%
word
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21}

# %%
word["sealand"]=0.00027
word
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'sealand': 0.00027}

# %%
"sealand" in word
# Out:
# True

# %%
word["sealand"] = 0.000028
word
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'sealand': 2.8e-05}

# %%
del(word["sealand"])
word
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21}

# %% [markdown]
# **Liste vs. dictionnaire**
#
# *Liste*
#
# - Sélectionner
# - mettre à jour
# - supprimer avec []
# - Indexé par plage de numéros
# - Collection de valeurs:l'ordre      importe, pour la sélection de sous-ensembles entiers
#
# *Dictionnaire*
#
# - Sélectionner
# - mettre à jour
# - supprimer avec []
# - Indexé par des clés uniques
# - Table de recherche avec
# clés uniques

# %% [markdown]
# **Pandas**

# %%
df
# Out:
#   Unnamed: 0       country    capital    area  population
# 0         BR        Brazil   Brasilia   8.516      200.40
# 1         RU        Russia     Moscow  17.100      143.50
# 2         IN         India  New Delhi   3.286     1252.00
# 3         CH         China    Beijing   9.597     1357.00
# 4         SA  South Africa   Pretoria   1.221       52.98

# %%
dict = {
    "country": ["Brazil","Russia","India","China","South Africa"],
    "capital":["Brasilia","Moscow","New Delhi","Beijing","Pretoria"],

}
