# %% [markdown]
# #**Importation de données intermédiaire en Python**
#
# + *2 heures*
# + *7 Vidéos*
# + *28 Exercices*
# + *154 530 Participants*
# + *2 300 XP*
#
# ##**Description du cours**
#
# + ***En tant que scientifique des données, vous devrez nettoyer les données, les démêler et les démêler, les visualiser, créer des modèles prédictifs et interpréter ces modèles. Avant de pouvoir le faire, cependant, vous devrez savoir comment obtenir des données dans Python. Dans la préquelle de ce cours, vous avez appris de nombreuses façons d'importer des données dans Python : à partir de fichiers plats tels que .txt et .csv ; à partir de fichiers natifs d'autres logiciels tels que les feuilles de calcul Excel, les fichiers Stata, SAS et MATLAB ; et à partir de bases de données relationnelles telles que SQLite et PostgreSQL. Dans ce cours, vous allez étendre cette base de connaissances en apprenant à importer des données depuis le Web et en extrayant des données d'interfaces de programmation d'applications (API) telles que l'API de streaming Twitter, qui nous permet de diffuser des tweets en temps réel.***
#
# ####**1) Importer des données depuis Internet**
#
# + ***Le Web est une riche source de données à partir de laquelle vous pouvez extraire différents types d'informations et de conclusions. Dans ce chapitre, vous apprendrez comment récupérer des données sur le Web, qu'elles soient stockées dans des fichiers ou au format HTML. Vous apprendrez également les bases du grattage et de l'analyse des données Web.***
#
# |OBJECTIFS|
# |------------------|
# Importation de fichiers plats à partir du Web
# Importer des fichiers plats depuis le web : à vous de jouer !
# Ouverture et lecture de fichiers plats à partir du Web
# Importation de fichiers non plats à partir du Web
# Requêtes HTTP pour importer des fichiers depuis le Web
# Exécution de requêtes HTTP en Python à l'aide d'urllib
# Impression des résultats de la requête HTTP en Python à l'aide d'urllib
# Exécution de requêtes HTTP en Python à l'aide de requêtes
# Scraper le web en Python
# Parsing HTML avec BeautifulSoup
# Transformer une page Web en données à l'aide de BeautifulSoup : obtenir le texte
# Transformer une page Web en données à l'aide de BeautifulSoup : obtenir les hyperliens
#
# ####**2) Interagir avec les API pour importer des données depuis le Web**
#
# + ***Dans ce chapitre, vous comprendrez mieux comment importer des données depuis le Web. Vous apprendrez les bases de l'extraction de données à partir d'API, vous comprendrez l'importance des API et vous vous entraînerez à extraire des données en plongeant dans les API OMDB et Library of Congress.***
#
# |OBJECTIFS|
# |------------------|
# Introduction aux API et JSON
# Quiz éclair : qu'est-ce qu'un JSON exactement ?
# Charger et explorer un JSON
# Quiz pop : Explorer votre JSON
# API et interaction avec le World Wide Web
# Quiz instantané : Qu'est-ce qu'une API ?
# Requêtes API
# JSON – du Web à Python
# Vérification de l'API Wikipedia
#
# ####**3) Plonger dans l'API Twitter**
#
# + ***Dans ce chapitre, vous consoliderez vos connaissances sur l'interaction avec les API dans une plongée approfondie dans l'API de streaming Twitter. Vous apprendrez à diffuser des données Twitter en temps réel, à les analyser et à les visualiser.***
#
# |OBJECTIFS|
# |------------------|
# L'API Twitter et l'authentification
# Tweets en streaming
# Chargez et explorez vos données Twitter
# Données Twitter vers DataFrame
# Un peu d'analyse de texte Twitter
# Tracer vos données Twitter
# Dernières pensées

# %% [markdown]
# ####**1. Importation de fichiers plats depuis le Web**
#
# + ***Vous pouvez désormais importer des données dans Python à partir de toutes sortes de types de fichiers :***
#
# ####**2. Vous êtes déjà doué pour l'importation !**
#
# + ***les fichiers plats tels que les points txt et les points csv, d'autres types de fichiers tels que les fichiers marinés, les feuilles de calcul Excel et les fichiers MATLAB. Vous avez également acquis une expérience précieuse dans l'interrogation de bases de données relationnelles pour en importer des données à l'aide de SQL. Vous avez vraiment parcouru un long chemin, félicitations! Cependant, toutes ces compétences impliquent l'importation de données à partir de fichiers que vous avez localement. La plupart du temps, en tant que data scientist, ces compétences ne seront pas tout à fait suffisantes car vous n'aurez pas toujours les données dont vous avez besoin. Vous devrez l'importer depuis le Web.***
#
# ####**3. Pouvez-vous importer des données Web ?**
#
# + ***Supposons, par exemple, que vous souhaitiez importer l'ensemble de données Wine Quality à partir du référentiel d'apprentissage automatique hébergé par l'Université de Californie à Irvine. Comment obtenez-vous ce fichier sur le Web ? Vous pouvez maintenant utiliser votre navigateur Web préféré pour accéder à l'URL appropriée, pointer et cliquer sur les hyperliens appropriés pour télécharger le fichier, mais cela pose quelques problèmes. Premièrement, il n'est pas écrit en code et pose donc des problèmes de reproductibilité. Si un autre Data Scientist souhaitait reproduire votre workflow, il devrait nécessairement le faire en dehors de Python. Deuxièmement, il n'est PAS évolutif. Si vous vouliez télécharger cent ou mille fichiers de ce type, cela prendrait respectivement cent ou mille fois plus de temps, alors que si vous l'écriviez en code, votre flux de travail pourrait évoluer.***
#
# ####**4. Vous apprendrez à…**
#
# + ***Comme la reproductibilité et l'évolutivité sont au cœur même de la science des données, vous allez apprendre dans ce chapitre comment utiliser le code Python pour importer et enregistrer localement des ensembles de données à partir du World Wide Web. Vous apprendrez également à charger de tels ensembles de données dans des cadres de données pandas directement à partir du Web, qu'il s'agisse de fichiers plats ou non. Ensuite, vous placerez ces compétences dans le contexte plus large de la création de requêtes HTTP. En particulier, vous effectuerez des requêtes `HTTP GET, ce qui signifie en clair obtenir des données à partir du Web`. Vous utiliserez ces nouvelles compétences de requête pour apprendre les bases du grattage du code HTML sur Internet et vous utiliserez le merveilleux package Python BeautifulSoup pour analyser le code HTML et le transformer en données. Il existe un certain nombre de packages intéressants pour nous aider à importer des données Web : ici, vous Nous allons nous familiariser avec les paquets `urllib et requests`. Nous allons d'abord vérifier urllib :***
#
# ####**5. Le paquet urllib**
#
# + **"Ce module fournit une interface de haut niveau pour récupérer des données sur le World Wide Web. En particulier, la fonction urlopen est similaire à la fonction intégrée open, mais accepte les URL (Universal Resource Locators) au lieu des noms de fichiers." Passons maintenant directement à l'importation de données depuis le Web avec un exemple, l'importation de l'ensemble de données Wine Quality pour le vin blanc. Ne soyez pas jaloux : dans le premier exercice interactif, ce sera à vous d'importer le jeu de données du vin rouge !**
#
# ####**6. Comment automatiser le téléchargement de fichiers en Python**
#
# + ***Tout ce que nous avons fait ici est d'importer une fonction appelée urlretrieve à partir du sous-package de requête du package urllib, nous avons attribué l'URL pertinente sous forme de chaîne à la variable url. Nous avons ensuite utilisé la fonction urlretrieve pour écrire le contenu de l'url dans un fichier 'winequality-white dot csv'. A vous maintenant de faire la même chose mais pour le vin rouge !***
#
# ####**7. Entraînons-nous !**
#
# + ***Dans les exercices interactifs suivants, vous découvrirez également comment utiliser pandas pour charger le contenu de fichiers Web directement dans des dataframes pandas sans avoir à les enregistrer localement. Bon piratage !***

# %%
import seaborn as sns
sns.set_style("darkgrid")

# %% [markdown]
# ###**EXERCICES**
#
# ####**Importer des fichiers plats depuis le web : à vous de jouer !**
#
# + ***Vous êtes sur le point d'importer votre premier fichier depuis le Web ! Le fichier plat que vous importerez proviendra du référentiel [Machine Learning'winequality-red.csv'](https://archive.ics.uci.edu/datasets) de l'Université de Californie à Irvine . Le fichier plat contient des données tabulaires sur les propriétés physicochimiques du vin rouge, telles que le pH, la teneur en alcool et en acide citrique, ainsi que l'évaluation de la qualité du vin.***
#
# + L'URL du fichier est :
#
#   + *'https://assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'*
#
# + *Après l'avoir importé, vous vérifierez votre répertoire de travail pour confirmer qu'il s'y trouve, puis vous le chargerez dans un pandasDataFrame.*
#
# ####**Instructions**
#
# + Importez la fonction urlretrieveà partir du sous-package urllib.request.
# + Affectez l'URL du fichier à la variable url.
# + Utilisez la fonction urlretrieve() pour enregistrer le fichier localement en tant que 'winequality-red.csv'.
# + Exécutez le code restant à charger 'winequality-red.csv'dans un DataFrame pandas et à imprimer sa tête sur le shell.

# %%
# Import package
from urllib.request import urlretrieve

# Import pandas
import pandas as pd

# Assign url of file: url
url = 'https://assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'

# Save file locally
urlretrieve(url, 'winequality-red.csv')

# Read file into a DataFrame and print its head
df = pd.read_csv('winequality-red.csv', sep=';')
print(df.head())
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# ####**Ouverture et lecture de fichiers plats à partir du Web**
#
# + ***Vous venez d'importer un fichier du Web, de l'enregistrer localement et de le charger dans un DataFrame. Si vous vouliez simplement charger un fichier du Web dans un DataFrame sans l'enregistrer au préalable localement, vous pouvez le faire facilement en utilisant pandas. En particulier, vous pouvez utiliser la fonction pd.read_csv() avec l'URL comme premier argument et le séparateur sepcomme deuxième argument.***
#
# + ***L'URL du fichier, encore une fois, est : ***
#
#   + *'https://assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'*
#
#
# ####**Instructions**
#
# + Affectez l'URL du fichier à la variable url.
# + Lire le fichier dans un DataFrame dfen utilisant pd.read_csv(), en rappelant que le séparateur dans le fichier est ';'.
# + Imprimer la tête du DataFrame df.
# + Exécutez le reste du code pour tracer l'histogramme de la première fonctionnalité dans le DataFrame df.

# %%
# Import packages
import matplotlib.pyplot as plt
import pandas as pd

# Assign url of file: url
url = 'https://assets.datacamp.com/production/course_1606/datasets/winequality-red.csv'

# Read file into a DataFrame: df
df = pd.read_csv(url, sep=';')

# Print the head of the DataFrame
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Plot first column of df
df.iloc[:, 0].hist(figsize=(20,12))
plt.xlabel('fixed acidity (g(tartaric acid)/dm$^3$)')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ####**Importation de fichiers non plats à partir du Web**
#
# + ***Bravo! Vous venez de charger un fichier plat du Web dans un DataFrame sans l'enregistrer au préalable en local à l'aide de la pandasfonction `pd.read_csv()`. Cette fonction est super cool car elle a des parents proches qui vous permettent de charger tous les types de fichiers, pas seulement les fichiers plats. Dans cet exercice interactif, vous utiliserez `pd.read_excel()`pour importer une feuille de calcul Excel.***
#
#
# + ***L'URL de la feuille de calcul est***
#
#   + *'https://assets.datacamp.com/course/importing_data_into_r/latitude.xls'*
#
# + ***Votre travail consiste pd.read_excel() à lire dans toutes ses feuilles, à imprimer les noms des feuilles, puis à imprimer l'en-tête de la première feuille en utilisant son nom et non son index.***
#
# + ***Notez que la sortie de pd.read_excel() est un dictionnaire Python avec les noms de feuilles comme clés et les DataFrames correspondants comme valeurs correspondantes.***
#
# ####**Instructions**
#
# + Affectez l'URL du fichier à la variable url.
# + Lisez le fichier dans url un dictionnaire xls en vous pd.read_excel()rappelant que, pour importer toutes les feuilles, vous devez passer None à l'argument sheet_name.
# + Imprimez les noms des feuilles dans la feuille de calcul Excel ; ce seront les clés du dictionnaire xls.
# + Imprimez l'en-tête de la première feuille en utilisant le nom de la feuille, pas l'index de la feuille ! Le nom de la feuille est'1700'

# %%
# Import package
import pandas as pd

# Assign url of file: url
url= 'http://s3.amazonaws.com/assets.datacamp.com/course/importing_data_into_r/latitude.xls'

# Read in all sheets of Excel file: xls
xls= pd.read_excel(url, sheet_name=None)

# Print the sheetnames to the shell
print(xls.keys())
# Out:
# dict_keys(['1700', '1900'])

# %%
# Print the head of the first sheet (using its name, NOT its index)
print(xls['1700'].head())
# Out:
#                  country       1700
# 0            Afghanistan  34.565000
# 1  Akrotiri and Dhekelia  34.616667
# 2                Albania  41.312000
# 3                Algeria  36.720000
# 4         American Samoa -14.307000

# %% [markdown]
# ####**1. Requêtes HTTP pour importer des fichiers depuis le Web**
#
# + ***Félicitations pour l'importation de vos premières données Web ! Pour importer des fichiers depuis le Web,nous avons utilisé la fonction urlretrieve à partir des requêtes urllib dot.***
#
# ####**2.URL**
#
#  + ***Décompressons maintenant un peu cela et, ce faisant, comprenons quelques éléments sur le fonctionnement d'Internet. URL signifie Uniform ou Universal Resource Locator et tout ce qu'ils sont vraiment sont des références à des ressources Web. La grande majorité des URL sont des adresses Web, mais elles peuvent faire référence à quelques autres éléments, tels que les protocoles de transfert de fichiers (FTP) et l'accès à la base de données. Nous nous concentrerons actuellement sur les URL qui sont des adresses Web OU les emplacements de sites Web. Une telle URL se compose de 2 parties, un identifiant de protocole http ou https et un nom de ressource tel que datacamp dot com. La combinaison de l'identifiant de protocole et du nom de la ressource spécifie de manière unique l'adresse Web ! Pour expliquer les URL, j'ai introduit un autre acronyme***
#
# ####**3.HTTP**
#
# + ***http, qui lui-même signifie HyperText Transfer Protocol. Wikipedia fournit une excellente description de HTTP. "Le protocole de transfert hypertexte (HTTP) est un protocole d'application pour les systèmes d'information distribués, collaboratifs et hypermédias. HTTP est le fondement de la communication de données pour le World Wide Web." Notez que HTTPS est une forme plus sécurisée de HTTP. Chaque fois que vous accédez à un site Web, vous envoyez en fait une requête HTTP à un serveur. Cette requête est connue sous le nom de requête GET, de loin le type de requête HTTP le plus courant. Nous effectuons en fait une requête GET lors de l'utilisation de la fonction urlretrieve. L'ingéniosité d'urlretrieve réside également dans le fait qu'il ne fait pas seulement une requête GET mais enregistre également les données pertinentes localement. Dans ce qui suit, vous apprendrez à effectuer davantage de requêtes GET pour stocker des données Web dans votre environnement. En particulier, vous comprendrez comment obtenir les données HTML d'une page Web. HTML signifie Hypertext Markup Language et est le langage de balisage standard pour le Web.***
#
# ####**4. Requêtes GET utilisant urllib**
#
# + ***Pour extraire le code HTML de la page d'accueil de wikipedia, vous importez les fonctions nécessaires, spécifiez l'URL, conditionnez la requête GET à l'aide de la fonction Request, envoyez la requête et attrapez la réponse à l'aide de la fonction urlopen. Cela renvoie un objet HTTPResponse, qui a une méthode de lecture associée. Vous appliquez ensuite cette méthode de lecture à la réponse, qui renvoie le code HTML sous forme de chaîne, que vous stockez dans la variable html. N'oubliez pas d'être poli et fermez la réponse !***
#
# ####**5. Requêtes GET utilisant des requêtes**
#
# + ***Maintenant, nous allons faire la même chose, mais ici nous allons utiliser le package requests, qui fournit une merveilleuse API pour faire des requêtes. Selon le site Web du package de demandes. "Requests vous permet d'envoyer des requêtes HTTP/1 point 1 organiques et alimentées par l'herbe, sans avoir besoin de travail manuel." et les organisations suivantes affirment utiliser les demandes en interne : "le gouvernement de Sa Majesté, Amazon, Google, Twilio, NPR, Obama pour l'Amérique, Twitter, Sony et les institutions fédérales américaines qui préfèrent rester anonymes".***
#
# ####**6. Requêtes GET utilisant des requêtes**
#
# + ***De plus, "Requests est l'un des packages Python les plus téléchargés de tous les temps, avec plus de 7 000 000 de téléchargements chaque mois. Tous les enfants cool le font !" Voyons maintenant les demandes au travail. Ici, vous importez les demandes de package, spécifiez l'URL, empaquetez la demande, envoyez la demande et attrapez la réponse avec une seule fonction demandes dot get; appliquez la méthode text à la réponse qui renvoie le code HTML sous forme de chaîne.***
#
# ####**7. Entraînons-nous !**
#
# + ***Cela me suffit pour le moment. Laissez-vous tenter par l'extraction de code HTML du Web à l'aide de requêtes GET ! OBTENEZ le codage !***

# %% [markdown]
# ###**EXERCICES**
#
# ####**Exécution de requêtes HTTP en Python à l'aide d'urllib**
#
# + ***Maintenant que vous connaissez les bases des requêtes HTTP GET, il est temps d'en effectuer certaines vous-même. Dans cet exercice interactif, vous allez envoyer un ping à nos propres serveurs DataCamp pour effectuer une requête GET afin d'extraire des informations du premier exercice de codage de ce cours, "https://campus.datacamp.com/courses/1606/4135?ex=2".***
#
# + *Dans le prochain exercice, vous allez extraire le code HTML lui-même. À l'heure actuelle, cependant, vous allez empaqueter et envoyer la demande, puis intercepter la réponse.*
#
# ####**Instructions**
#
# + Importez les fonctions urlopenet Requestdepuis le sous-package urllib.request.
# + Emballez la requête dans l'URL ⏸:
#
#   + "https://campus.datacamp.com/courses/1606/4135?ex=2"
#
#   + à l'aide de la `fonction Request()` et attribuez-la à request.
#
# + Envoyez la requête et attrapez la réponse dans la variable response avec la fonction `urlopen()`.
# + Exécutez le reste du code pour voir le type de données responseet pour fermer la connexion !

# %%
# Import packages
from urllib.request import urlopen, Request

# Specify the url
url = "https://campus.datacamp.com/courses/1606/4135?ex=2"

# This packages the request: request
request= Request(url)

# Sends the request and catches the response: response
response=urlopen(request)

# Print the datatype of response
print(type(response))

# Be polite and close the response!
response.close()
# Out:
# <class 'http.client.HTTPResponse'>

# %% [markdown]
# ####**Impression des résultats de la requête HTTP en Python à l'aide d'urllib**
#
# + Vous venez de empaqueter et d'envoyer une requête GET à :
#
#   + **"https://campus.datacamp.com/courses/1606/4135?ex=2"**
#
#   + ***puis d'attraper la réponse. Vous avez vu qu'une telle réponse est un `http.client.HTTPResponseobjet`. La question demeure : que pouvez-vous faire avec cette réponse ?***
#
# + Eh bien, comme il provient d'une page HTML, vous pourriez le lire pour extraire le HTML et, en fait, un tel `http.client.HTTPResponseobjet` a une méthode `read()` associée.
# + *Dans cet exercice, vous vous baserez sur votre excellent travail précédent pour extraire la réponse et imprimer le code HTML.*
#
# ####**Instructions**
#
# + Envoyez la requête et attrapez la réponse dans la variable responseavec la fonction `urlopen()`, comme dans l'exercice précédent.
# Extrayez la réponse à l'aide de la méthode `read()` et stockez le résultat dans la variable html.
# + Imprimez la chaîne html.
# + Appuyez sur soumettre pour effectuer tout ce qui précède et pour fermer la réponse : soyez ordonné !

# %%
# Import packages
from urllib.request import urlopen, Request

# Specify the url
url = "https://campus.datacamp.com/courses/1606/4135?ex=2"

# This packages the request
request = Request(url)

# Sends the request and catches the response: response
response= urlopen(request)

# Extract the response: html
html=response.read()

# Print the html
print(html)

# Be polite and close the response!
response.close()
# Out:
# b'<!doctype html><html lang="en"><head><link rel="apple-touch-icon-precomposed" sizes="57x57" href="/campus/apple-touch-icon-57x57.png"><link rel="apple-touch-icon-precomposed" sizes="114x114" href="/campus/apple-touch-icon-114x114.png"><link rel="apple-touch-icon-precomposed" sizes="72x72" href="/campus/apple-touch-icon-72x72.png"><link rel="apple-touch-icon-precomposed" sizes="144x144" href="/campus/apple-touch-icon-144x144.png"><link rel="apple-touch-icon-precomposed" sizes="60x60" href="/campus/apple-touch-icon-60x60.png"><link rel="apple-touch-icon-precomposed" sizes="120x120" href="/campus/apple-touch-icon-120x120.png"><link rel="apple-touch-icon-precomposed" sizes="76x76" href="/campus/apple-touch-icon-76x76.png"><link rel="apple-touch-icon-precomposed" sizes="152x152" href="/campus/apple-touch-icon-152x152.png"><link rel="icon" type="image/png" href="/campus/favicon.ico"><link rel="icon" type="image/png" href="/campus/favicon-196x196.png" sizes="196x196"><link rel="icon" type
# ...

# %% [markdown]
# ####**Exécution de requêtes HTTP en Python à l'aide de requêtes**
#
# + ***Maintenant que vous savez comment faire des requêtes HTTP à l'aide du package urllib, vous allez découvrir comment faire de même en utilisant la bibliothèque de requêtes de niveau supérieur. Vous allez à nouveau envoyer un ping aux serveurs DataCamp pour leur page:***
#
#   + **"http://www.datacamp.com/teach/documentation"**.
#
# + *Notez que contrairement aux exercices précédents utilisant urllib, vous n'avez pas besoin de fermer la connexion lorsque vous utilisez des requêtes !*
#
# ####**Instructions**
#
# + Importez le paquet requests.
# + Attribuez l'URL qui vous intéresse à la variable url.
# + Assemblez la requête à l'URL, envoyez la requête et attrapez la réponse avec une seule fonction `requests.get()`, en affectant la réponse à la variable `r`.
# + Utilisez l'attribut text de l'objet rpour renvoyer le code HTML de la page Web sous forme de chaîne ; stocker le résultat dans une variable text.
# + Appuyez sur Soumettre pour imprimer le code HTML de la page Web.

# %%
# Import package
import requests

# Specify the url: url
url="http://www.datacamp.com/teach/documentation"

# Packages the request, send the request and catch the response: r
r=requests.get(url)

# Extract the response: text
text=r.text

# Print the html
print(text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
#     <title>Just a moment...</title>
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge">
#     <meta name="robots" content="noindex,nofollow">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
#     <link href="/cdn-cgi/styles/challenges.css" rel="stylesheet">
#     <meta http-equiv="refresh" content="35">
#
# </head>
# <body class="no-js">
#     <div class="main-wrapper" role="main">
#     <div class="main-content">
#         <noscript>
#             <div id="challenge-error-title">
#                 <div class="h2">
#                     <span class="icon-wrapper">
#                         <div class="heading-icon warning-icon"></div>
#                     </span>
#                     <span id="challenge-error-text">
#                         Enable JavaScript and cookies to continue
#                     </span>
# ...

# %% [markdown]
# ####**1. Scraper le web en Python**
#
# + ***Ouah! vous venez de récupérer des données HTML sur le Web et vous l'avez fait en utilisant deux packages différents, urllib et requests. Vous avez également vu que les requêtes fournissaient une interface de niveau supérieur dans la mesure où vous deviez écrire moins de lignes pour récupérer le code HTML pertinent sous forme de chaîne.***
#
# ####**2.HTML**
#
# + ***Vous avez le code HTML de votre page qui vous intéresse, mais généralement, le code HTML est un humble mélange de données non structurées et structurées. Un mot sur ces termes : Les données structurées sont des données qui ont un modèle de données prédéfini ou qui sont organisées de manière définie. Les données non structurées sont des données qui ne possèdent aucune de ces propriétés. Le HTML est intéressant car, bien qu'il s'agisse en grande partie de texte non structuré, il contient des balises qui déterminent où, par exemple, les en-têtes peuvent être trouvés et les hyperliens.***
#
# ####**3. BeautifulSoup**
#
# + ***En général, pour transformer le code HTML que vous avez extrait du World Wide Web en données utiles, vous devez l'analyser et en extraire des données structurées. Dans cette vidéo et les prochains exercices interactifs, nous allons fournir une brève introduction sur la façon dont vous pouvez effectuer de telles tâches à l'aide du package Python BeautifulSoup. Permet de vérifier le site Web du package. Les premiers mots en haut sont : "Vous n'avez pas écrit cette horrible page. Vous essayez simplement d'en extraire des données. Beautiful Soup est là pour vous aider. Depuis 2004, il permet aux programmeurs d'économiser des heures ou des jours de travail. sur des projets de grattage d'écran à exécution rapide." Tout d'abord, un mot sur le nom du colis : BeautifulSoup ? Dans le développement Web, le terme «soupe de balises» fait référence à un code HTML structurellement ou syntaxiquement incorrect écrit pour une page Web. Ce que Beautiful Soup fait de mieux, c'est de redonner de la beauté à la soupe de tags et d'en extraire facilement des informations ! En fait, l'objet principal créé et interrogé lors de l'utilisation de ce package s'appelle BeautifulSoup et il a une méthode associée très importante appelée prettify ! Voyons maintenant BeautifulSoup dans Beautiful Action !***
#
# ####**4. BeautifulSoup**
#
# + ***Encore une fois, vous utilisez des requêtes pour récupérer le code HTML du Web. Ensuite, vous créez un objet BeautifulSoup à partir du code HTML résultant et embellissez.***
#
# ####**5. Soupe embellie**
#
# + ***En imprimant la soupe embellie et le HTML d'origine, vous pouvez voir que, par exemple, la soupe embellie est indentée de la manière dont vous vous attendez à ce qu'un HTML correctement écrit soit.***
#
# ####**6. Explorer BeautifulSoup**
#
# + ***Vous explorerez quelques-unes des méthodes que vous pouvez appliquer à votre code HTML simplifié dans les exercices suivants, telles que `title et get_text`, qui extraient respectivement `le titre et le texte`.***
#
# ####**7. Explorer BeautifulSoup**
#
# + ***Vous travaillerez également avec `la méthode Soupy find_all` afin d'extraire les URL de tous les hyperliens du HTML. Ce ne sont là que quelques-unes des nombreuses méthodes existantes dans BeautifulSoup pour extraire des données de HTML. Si, après avoir terminé ces exercices, vous avez soif de plus de BeautifulSoup, vous trouverez de nombreuses ressources intéressantes sur leur site Web.***
#
# ####**8. Entraînons-nous !**
#
# + ***D'accord, maintenant c'est à votre tour de plonger dans le bol de soupe proverbial ! Bon piratage !***

# %% [markdown]
# ###**EXERCICES**
#
# ####**Parsing HTML avec BeautifulSoup**
#
# + ***Dans cet exercice interactif, vous apprendrez à utiliser le package BeautifulSoup pour analyser , embellir et extraire des informations à partir de HTML. Vous récupérerez les données de la page Web de Guido van Rossum, [le propre dictateur bienveillant de Python pour la vie](https://en.wikipedia.org/wiki/Benevolent_dictator_for_life) . Dans les exercices suivants, vous allez embellir le code HTML, puis extraire le texte et les liens hypertexte.***
#
# + *L'URL d'intérêt est url = 'https://www.python.org/~guido/'.*
#
# ####**Instructions**
#
# + Importez la fonction `BeautifulSoup depuis le package bs4`.
# + Attribuez l'URL qui vous intéresse à la variable url.
# + Assemblez la requête à l'URL, envoyez la requête et attrapez la réponse avec une seule `fonction requests.get()`, en affectant la réponse à la variable `r`.
# + Utilisez l'attribut text de l'objet rpour renvoyer le code HTML de la page Web sous forme de chaîne ; stocker le résultat dans une variable html_doc.
# + Créez un objet `BeautifulSoup soup` à partir du code HTML résultant à l'aide de la fonction `BeautifulSoup()`.
# + Utilisez la méthode `prettify()` sur soup et affectez le résultat à pretty_soup.
# + Appuyez sur Soumettre pour imprimer en HTML embelli sur votre shell !

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url: url
url= 'https://www.python.org/~guido/'

# Package the request, send the request and catch the response: r
r=requests.get(url)

# Extracts the response as html: html_doc
html_doc=r.text

# Create a BeautifulSoup object from the HTML: soup
soup=BeautifulSoup(html_doc)

# Prettify the BeautifulSoup object: pretty_soup
pretty_soup= soup.prettify()

# Print the response
print(pretty_soup)
# Out:
# <html>
#  <head>
#   <title>
#    Guido's Personal Home Page
#   </title>
#  </head>
#  <body bgcolor="#FFFFFF" text="#000000">
#   <!-- Built from main -->
#   <h1>
#    <a href="pics.html">
#     <img border="0" src="images/IMG_2192.jpg"/>
#    </a>
#    Guido van Rossum - Personal Home Page
#    <a href="pics.html">
#     <img border="0" height="216" src="images/guido-headshot-2019.jpg" width="270"/>
#    </a>
#   </h1>
#   <p>
#    <a href="http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm">
#     <i>
#      "Gawky and proud of it."
#     </i>
#    </a>
#   </p>
#   <h3>
#    <a href="images/df20000406.jpg">
#     Who I Am
#    </a>
#   </h3>
#   <p>
#    Read
# my
#    <a href="http://neopythonic.blogspot.com/2016/04/kings-day-speech.html">
#     "King's
# Day Speech"
#    </a>
#    for some inspiration.
#   </p>
#   <p>
#    I am the author of the
#    <a href="http://www.python.org">
#     Python
#    </a>
# ...

# %% [markdown]
# ####**Transformer une page Web en données à l'aide de BeautifulSoup : obtenir le texte**
#
# + ***Comme promis, dans les exercices suivants, vous apprendrez les bases de l'extraction d'informations à partir d'une soupe HTML. Dans cet exercice, vous découvrirez comment extraire le texte de la page Web de la BDFL, ainsi que l'impression du titre de la page Web.***
#
# ####**Instructions**
#
# + Dans l'exemple de code, l'objet de réponse HTML html_doca déjà été créé : votre première tâche consiste à le soupeifier à l'aide de la fonction `BeautifulSoup()`et à affecter la soupe résultante à la variable soup.
# + Extrayez le titre de la soupe HTML soupà l'aide de l'attribut title et attribuez le résultat à `guido_title`.
# + Imprimez le titre de la page Web de Guido sur le shell à l'aide de la fonction `print()`.
# + Extrayez le texte de la soupe HTML soupà l'aide de la méthode `get_text()` et affectez-le à guido_text.
# + Appuyez sur soumettre pour imprimer le texte de la page Web de Guido sur le shell.

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url: url
url = 'https://www.python.org/~guido/'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extract the response as html: html_doc
html_doc = r.text

# Create a BeautifulSoup object from the HTML: soup
soup= BeautifulSoup(html_doc)

# Get the title of Guido's webpage: guido_title
guido_title=soup.title

# Print the title of Guido's webpage to the shell
print(guido_title)
# Out:
# <title>Guido's Personal Home Page</title>

# %%
# Get Guido's text: guido_text
guido_text=soup.text

# Print Guido's text to the shell
print(guido_text)
# Out:
# Guido's Personal Home Page
#
#
#
#
#
# Guido van Rossum - Personal Home Page
#
#
# "Gawky and proud of it."
# Who I Am
# Read
# my "King's
# Day Speech" for some inspiration.
#
# I am the author of the Python
# programming language.  See also my resume
# and my publications list, a brief bio, assorted writings, presentations and interviews (all about Python), some
# pictures of me,
# my new blog, and
# my old
# blog on Artima.com.  I am
# @gvanrossum on Twitter.
#
# I am currently a Distinguished Engineer at Microsoft.
# I have worked for Dropbox, Google, Elemental Security, Zope
# Corporation, BeOpen.com, CNRI, CWI, and SARA.  (See
# my resume.)  I created Python while at CWI.
#
# How to Reach Me
# You can send email for me to guido (at) python.org.
# I read everything sent there, but I receive too much email to respond
# to everything.
#
# My Name
# My name often poses difficulties for Americans.
#
# Pronunciation: in Dutch, the "G" in Guido is a hard G,
# ...

# %% [markdown]
# ####**Transformer une page Web en données à l'aide de BeautifulSoup : obtenir les hyperliens**
#
# + ***Dans cet exercice, vous découvrirez comment extraire les URL des liens hypertexte de la page Web de la BDFL. Dans le processus, vous deviendrez des amis proches avec la méthode de la soupe `find_all()`.***
#
# ####**Instructions**
#
# + Utilisez la méthode **`find_all()`** pour rechercher tous les hyperliens dans soup, en vous rappelant que les hyperliens sont définis par la balise HTML **`<a>mais passés à `find_all()`sans chevrons ; stocker le résultat dans la variable a_tags`**.
# + La variable a_tags est un ensemble de résultats : votre travail consiste maintenant à l'énumérer, à l'aide d'une boucle for, et à imprimer les URL réelles des hyperliens ; pour ce faire, pour chaque élément linkde a_tags, vous voulez `print() link.get('href')`.

# %%
# Import packages
import requests
from bs4 import BeautifulSoup

# Specify url
url = 'https://www.python.org/~guido/'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Extracts the response as html: html_doc
html_doc = r.text

# create a BeautifulSoup object from the HTML: soup
soup = BeautifulSoup(html_doc)

# Print the title of Guido's webpage
print(soup.title)
# Out:
# <title>Guido's Personal Home Page</title>

# %%
# Find all 'a' tags (which define hyperlinks): a_tags
a_tags= soup.find_all('a')

# Print the URLs to the shell
for link in a_tags:
    print(link.get('href'))
# Out:
# pics.html
# pics.html
# http://www.washingtonpost.com/wp-srv/business/longterm/microsoft/stories/1998/raymond120398.htm
# images/df20000406.jpg
# http://neopythonic.blogspot.com/2016/04/kings-day-speech.html
# http://www.python.org
# Resume.html
# Publications.html
# bio.html
# http://legacy.python.org/doc/essays/
# http://legacy.python.org/doc/essays/ppt/
# interviews.html
# pics.html
# http://neopythonic.blogspot.com
# http://www.artima.com/weblogs/index.jsp?blogger=12088
# https://twitter.com/gvanrossum
# Resume.html
# guido.au
# http://legacy.python.org/doc/essays/
# images/license.jpg
# http://www.cnpbagwell.com/audio-faq
# http://sox.sourceforge.net/
# images/internetdog.gif

# %% [markdown]
# ####**1. Introduction aux API et aux JSON**
#
# + ***Dans ce chapitre, vous explorerez l'extraction de données du Web encore plus loin en***
#
# ####**2. API**
#
# + ***apprendre à interagir avec les API ou les interfaces de programmation d'applications. Une API est un ensemble de protocoles et de routines permettant de créer et d'interagir avec des applications logicielles. En particulier, vous apprendrez à utiliser l'API Open Movie Database et, dans le chapitre suivant,***
#
# ####**3. API**
#
# + ***l'API Twitter pour extraire les données des deux applications, tout en découvrant les meilleures pratiques d'interaction API. Un formulaire standard pour le transfert de données via des API est***
#
# ####**4. JSON**
#
# + ***le format de fichier JSON, donc dans cette vidéo, nous allons concentrer notre attention sur ceux-ci. Ensuite, nous passerons à l'obtention de données à partir des API. JSON est un acronyme qui est l'abréviation de JavaScript Object Notation. Il s'agit d'un format de fichier né d'un besoin croissant de communication serveur-navigateur en temps réel qui ne reposerait pas nécessairement sur Flash ou Java. Il a été spécifié et popularisé pour la première fois par Douglas Crockford, un programmeur et entrepreneur américain. L'un des aspects intéressants des JSON est qu'ils sont lisibles par l'homme, c'est-à-dire qu'ils peuvent naturellement être lus par des humains contrairement, par exemple, aux fichiers picklés, comme nous l'avons vu dans le cours précédent. Comme ils sont lisibles par l'homme, vérifions-en un !***
#
# ####**5. JSON**
#
# + ***Ici, vous voyez un JSON de l'API OMDB OR Open Movie Database. En particulier, il s'agit de JSON contenant des informations sur le film Snakes on a Plane. Notez d'abord que le JSON se compose de paires nom-valeur séparées par des virgules. Cela vous rappellera les paires clé-valeur dans un dictionnaire Python ! Nous verrons dans un instant que, pour cette raison, lors du chargement de JSON dans Python, il est naturel de les stocker dans un dict. Les clés dans les JSON seront toujours des chaînes entre guillemets. Les valeurs peuvent être des chaînes, des entiers, des tableaux ou même des objets. Un tel objet peut même être un JSON, puis vous avez des JSON imbriqués, mais nous n'irons pas plus loin dans ceux-ci ici. Dans ce cas du JSON Snakes on a Plane, toutes les valeurs sont des chaînes et nous pouvons le voir à partir des guillemets.***
#
# ####**6. JSON**
#
# + ***La valeur correspondant à la clé 'Title' est le titre du film sous forme de chaîne : Snakes on a Plane.***
#
# ####**7. JSON**
#
# + ***La valeur correspondant à la clé 'Year' est l'année de sortie sous forme de chaîne : 2006 et ainsi de suite. Il y a le classement, le temps d'exécution, le réalisateur, les scénaristes, l'intrigue, la langue et bien plus encore ! Vous apprendrez bientôt à utiliser l'API OMDB et Python pour automatiser la récupération de ces données, mais vous découvrirez d'abord comment charger des JSON à partir d'un répertoire local.***
#
# ####**8. Charger des JSON en Python**
#
# + ***Disons que j'avais le JSON stocké dans mon répertoire de travail en tant que "snakes dot json". Pour charger le JSON dans mon environnement Python, je voudrais d'abord importer le package json, puis ouvrir une connexion au fichier et utiliser la fonction json dot load pour charger le JSON. Si je vérifie ensuite le type de données de json_data en exécutant `type(json_data)`, je vois que Python a intelligemment importé le JSON en tant que dictionnaire !***
#
# ####**9. Explorer les JSON en Python**
#
# + ***Pour imprimer les paires clé-valeur sur la console, je peux ensuite parcourir les paires clé-valeur à l'aide d'une boucle for. C'est maintenant à vous de tester vos compétences JSON***
#
# ####**10. Entraînons-nous !**
#
# + **Alors codez !**

# %% [markdown]
# ###**EXERCICES**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**Charger et explorer un JSON**
#
# + ***Maintenant que vous savez ce qu'est un JSON, vous allez en charger un dans votre environnement Python et l'explorer vous-même. Ici, vous allez charger le JSON 'a_movie.json'dans la variable json_data, qui sera un dictionnaire. Vous explorerez ensuite le contenu JSON en imprimant les paires clé-valeur dans le shell json_data.***
#
# ####**Instructions**
#
# + Chargez le JSON 'a_movie.json'dans la variable json_data dans le contexte fourni par l'instruction with .
# + Pour ce faire, utilisez la fonction `json.load()` dans le gestionnaire de contexte .
# + Utilisez une boucle for pour imprimer toutes les paires clé-valeur du dictionnaire json_data. Rappelez-vous que vous pouvez accéder à une valeur dans un dictionnaire en utilisant la syntaxe : `clé du dictionnaire [key]`.

# %%
import json

# %%
file = '/content/a_movie.json'

# %%
# Load JSON: json_data
with open(file) as json_file:
    json_data=json.load(json_file)

# Print each key-value pair in json_data
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# Actors:  Jesse Eisenberg, Rooney Mara, Bryan Barter, Dustin Fitzsimons
# Awards:  Won 3 Oscars. Another 165 wins & 168 nominations.
# BoxOffice:  $96,400,000
# Country:  USA
# DVD:  11 Jan 2011
# Director:  David Fincher
# Genre:  Biography, Drama
# Language:  English, French
# Metascore:  95
# Plot:  Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, but is later sued by two brothers who claimed he stole their idea, and the co-founder who was later squeezed out of the business.
# Poster:  https://images-na.ssl-images-amazon.com/images/M/MV5BMTM2ODk0NDAwMF5BMl5BanBnXkFtZTcwNTM1MDc2Mw@@._V1_SX300.jpg
# Production:  Columbia Pictures
# Rated:  PG-13
# Ratings:  [{'Source': 'Internet Movie Database', 'Value': '7.7/10'}, {'Source': 'Rotten Tomatoes', 'Value': '96%'}, {'Source': 'Metacritic', 'Value': '95/100'}]
# Released:  01 Oct 2010
# Response:  True
# Runtime:  120 min
# Title:  The Social Network
# Type:  movie
# ...

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**1. API et interaction avec le World Wide Web**
#
# + ***Félicitations pour avoir réussi votre cours intensif sur les JSON ! Les JSON sont partout et l'une des principales raisons motivantes pour apprendre à travailler avec eux en tant que Data Scientist est qu'une grande partie des données que vous obtiendrez des API sont regroupées sous forme de JSON.***
#
# ####**2. Ici, vous apprendrez**
#
# + ***Dans cette vidéo, vous apprendrez ce que sont les API, pourquoi elles sont si importantes et vous verrez un certain nombre d'exemples illustratifs. Dans les exercices interactifs suivants, vous acquerrez une pratique précieuse en vous connectant à diverses API, en extrayant et en analysant des données.***
#
# ####**3. Qu'est-ce qu'une API ?**
#
# + ***Alors, qu'est-ce qu'une API et pourquoi sont-elles si importantes ? En termes simples, une API est un ensemble de protocoles et de routines permettant de créer et d'interagir avec des applications logicielles. Une autre façon de penser est qu'une API est un ensemble de code qui permet à deux logiciels de communiquer entre eux. Par exemple, si vous vouliez diffuser des données Twitter en écrivant du code Python, vous utiliseriez l'API Twitter. Si vous vouliez automatiser l'extraction et le traitement des informations***
#
# ####**4. Qu'est-ce qu'une API ?**
#
# + ***de Wikipedia dans le langage de programmation de votre choix, vous pouvez le faire en utilisant l'API Wikipedia.***
#
# ####**5. Les API sont partout**
#
# + ***L'utilisation de telles API est désormais devenue un moyen standard d'interagir avec de telles applications. Twitter dispose d'une API utilisée par les sociétés de marketing et les spécialistes des sciences sociales engagés dans la recherche sur les réseaux sociaux.***
#
# ####**6. Les API sont partout**
#
# + ***Uber,***
#
# ####**7. Les API sont partout**
#
# + ***Facebook et***
#
# ####**8. Les API sont partout**
#
# + ***Instagram a tous des API. Voyons maintenant comment se connecter à une API et comment en extraire des données.***
#
# ####**9. Connexion à une API en Python**
#
# + ***Dans cet exemple, nous allons extraire les données de film de l'API Open Movie Database, ou OMDB. Encore une fois, vous utiliserez la bibliothèque de requêtes toujours élégante. Vous importez des requêtes et affectez l'URL qui vous intéresse à la variable url. Ensuite, vous empaquetez et envoyez la demande à l'URL, qui décrit votre requête d'API, et récupérez la réponse dans une ligne de code. Merci encore, demandes de colis ! Un autre aspect vraiment intéressant du package de requêtes est que les objets Response, tels que r, ont une méthode associée json, qui est un décodeur JSON intégré lorsque nous traitons des données JSON. Cela renvoie un dictionnaire et nous pouvons ensuite imprimer toutes les paires clé-valeur pour vérifier ce que nous avons extrait de l'API OMBD !***
#
# ####**10. Quelle était cette URL ?**
#
# + ***Maintenant, la dernière chose à discuter est de savoir comment l'URL que nous avons utilisée a réellement extrait les données de l'API. Pour ce faire, divisons-le en morceaux. Le http signifie que nous faisons une requête HTTP, le 'www dot omdb dot api' que nous interrogeons l'API OMDB, puis il y a le "?t équivaut à des pirates" qui est la partie vraiment intéressante et quelque chose que nous n'avons pas discuté encore dans ce cours. Cette chaîne qui commence par un point d'interrogation est appelée chaîne de requête. Les chaînes de requête sont des parties d'URL qui ne rentrent pas nécessairement dans une structure de chemin hiérarchique conventionnelle. Ce qui suit le point d'interrogation dans la chaîne de requête est la requête que nous adressons à l'API OMBD. La requête que nous venons de faire était simple : la requête 't equals hackers' demandait à l'API de retourner les données sur le film avec le titre Hackers. Le 't'***
#
# ####**11. API OMDb**
#
# + ***Nous savions que c'était comment effectuer une telle requête à partir de la documentation sur la page d'accueil de l'API OMDB. Sous "Utilisation" ici, ils indiquent explicitement que "Envoyez toutes les demandes de données à : http:// www point omdbapi point com /?".***
#
# ####**12. API OMDb**
#
# + ***Ils ont également une table de paramètres de chaîne de requête qui montre comment interroger un titre particulier ou un ID de film particulier.***
#
# ####**13. C'est une URL normale !**
#
# + ***Il convient également de mentionner qu'il n'y a rien de spécial à propos de cette URL et que vous pouvez donc également y accéder dans le navigateur de votre choix. Cela ressemblera généralement à ceci. J'aime utiliser une extension Chrome appelée formateur JSON pour le rendre un peu plus joli. Bien. Maintenant que vous savez tout sur les API et que vous avez une compréhension pratique de base de la façon de les interroger,***
#
# ####**14. Entraînons-nous !**
#
# + ***vous permet d'écrire du Python pour extraire des données d'un certain nombre d'API ! Bon codage !***

# %% [markdown]
# ###**EXERCICES**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ####**Requêtes API**
#
# + ***C'est maintenant à votre tour d'extraire des données de films de l'Open Movie Database (OMDB) à l'aide de leur API. Le film sur lequel vous allez interroger l'API est The Social Network . Rappelons que, dans la vidéo, pour interroger l'API sur le film Hackers , la chaîne de requête d'Hugo était 'http://www.omdbapi.com/?t=hackers'et avait un seul argument t=hackers.***
#
# + ***Remarque : récemment, OMDB a changé son API : vous devez désormais également spécifier une clé API. Cela signifie que vous devrez ajouter un autre argument à l'URL : apikey=72bc447a.***
#
# ####**Instructions**
#
# + Importez le paquet requests.
# + Attribuez à la variable url l'URL d'intérêt afin de rechercher *'http://www.omdbapi.com'* les données correspondant au film The Social Network . La chaîne de requête doit avoir deux arguments :
#  + `apikey=72bc447aet t=the+social+network`.
# + Vous pouvez les combiner comme suit :
#   + `apikey=72bc447a&t=the+social+network`.
# + Imprimez le texte de l'objet de réponse r en utilisant son textattribut et en transmettant le résultat à la fonction print().

# %%
# Import requests package
import requests 

# Assign URL to variable: url
url='http://www.omdbapi.com/?apikey=72bc447a&t=the+social+network'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Print the text of the response
print(r.text)
# Out:
# {"Title":"The Social Network","Year":"2010","Rated":"PG-13","Released":"01 Oct 2010","Runtime":"120 min","Genre":"Biography, Drama","Director":"David Fincher","Writer":"Aaron Sorkin, Ben Mezrich","Actors":"Jesse Eisenberg, Andrew Garfield, Justin Timberlake","Plot":"As Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, he is sued by the twins who claimed he stole their idea and by the co-founder who was later squeezed out of the business.","Language":"English, French","Country":"United States","Awards":"Won 3 Oscars. 173 wins & 186 nominations total","Poster":"https://m.media-amazon.com/images/M/MV5BOGUyZDUxZjEtMmIzMC00MzlmLTg4MGItZWJmMzBhZjE0Mjc1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg","Ratings":[{"Source":"Internet Movie Database","Value":"7.8/10"},{"Source":"Rotten Tomatoes","Value":"96%"},{"Source":"Metacritic","Value":"95/100"}],"Metascore":"95","imdbRating":"7.8","imdbVotes":"723,634","imdbID":"tt1285016","Type":"movie","D
# ...

# %% [markdown]
# ####**JSON – du Web à Python**
#
# + ***Waouh, félicitations ! Vous venez d'interroger votre première API par programmation en Python et d'imprimer le texte de la réponse au shell. Cependant, comme vous le savez, votre réponse est en fait un JSON, vous pouvez donc faire mieux et décoder le JSON. Vous pouvez ensuite imprimer les paires clé-valeur du dictionnaire résultant. C'est ce que vous allez faire maintenant !***
#
# ####**Instructions**
#
# + Transmettez la variable url à la fonction requests.get() afin d'envoyer la requête appropriée et d'attraper la réponse, en attribuant le message de réponse résultant à la variable r.
# + Appliquez la méthode json() à l'objet de réponse ret stockez le dictionnaire résultant dans la variable json_data.
# + Appuyez sur soumettre pour imprimer les paires clé-valeur du dictionnaire json_data dans le shell.

# %%
# Import package
import requests

# Assign URL to variable: url
url = 'http://www.omdbapi.com/?apikey=72bc447a&t=social+network'

# Package the request, send the request and catch the response: r
r=requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data=r.json()

# Print each key-value pair in json_data
for k in json_data.keys():
    print(k + ': ', json_data[k])
# Out:
# Title:  The Social Network
# Year:  2010
# Rated:  PG-13
# Released:  01 Oct 2010
# Runtime:  120 min
# Genre:  Biography, Drama
# Director:  David Fincher
# Writer:  Aaron Sorkin, Ben Mezrich
# Actors:  Jesse Eisenberg, Andrew Garfield, Justin Timberlake
# Plot:  As Harvard student Mark Zuckerberg creates the social networking site that would become known as Facebook, he is sued by the twins who claimed he stole their idea and by the co-founder who was later squeezed out of the business.
# Language:  English, French
# Country:  United States
# Awards:  Won 3 Oscars. 173 wins & 186 nominations total
# Poster:  https://m.media-amazon.com/images/M/MV5BOGUyZDUxZjEtMmIzMC00MzlmLTg4MGItZWJmMzBhZjE0Mjc1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SX300.jpg
# Ratings:  [{'Source': 'Internet Movie Database', 'Value': '7.8/10'}, {'Source': 'Rotten Tomatoes', 'Value': '96%'}, {'Source': 'Metacritic', 'Value': '95/100'}]
# Metascore:  95
# imdbRating:  7.8
# imdbVotes:  723,634
# imdbID:  tt1285016
# ...

# %% [markdown]
# ####**Vérification de l'API Wikipedia**
# + Vous vous débrouillez si bien et vous vous amusez tellement que nous allons vous lancer une autre API : l'API Wikipedia (documentée [ici](https://www.mediawiki.org/wiki/API:Main_page)).
# + Vous saurez comment trouver et extraire des informations de la page Wikipédia pour Pizza .
# + Ce qui devient un peu sauvage ici, c'est que votre requête renverra des JSON imbriqués , c'est-à-dire des JSON avec des JSON, mais Python peut gérer cela car il les traduira en dictionnaires dans des dictionnaires.
#
# + L'URL qui demande la requête pertinente à partir de l'API Wikipedia est
#
#     + *https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=pizza*
#
# ####**Instructions**
#
# + Attribuez l'URL appropriée à la variable url.
# + Appliquez la méthode json() à l'objet de réponse r et stockez le dictionnaire résultant dans la variable json_data.
# + La variable pizza_extract contient le code HTML d'un extrait de la page Pizza de Wikipedia sous forme de chaîne ; utilisez la fonction print() pour imprimer cette chaîne dans le shell.

# %%
# Import package
import requests

# Assign URL to variable: url
url='https://en.wikipedia.org/w/api.php?action=query&prop=extracts&format=json&exintro=&titles=pizza'

# Package the request, send the request and catch the response: r
r = requests.get(url)

# Decode the JSON data into a dictionary: json_data
json_data=r.json()

# Print the Wikipedia page extract
pizza_extract = json_data['query']['pages']['24768']['extract']

# %%
print(pizza_extract)
# Out:
# <link rel="mw-deduplicated-inline-style" href="mw-data:TemplateStyles:r1033289096">
# <p class="mw-empty-elt">
# </p>
# <p><b>Pizza</b> (<span><small>English: </small></span> <i title="English pronunciation respelling"><span>PEET</span>-sə</i>, <small>Italian: </small><span title="Representation in the International Phonetic Alphabet (IPA)" lang="it-Latn-fonipa">[ˈpittsa]</span>, <small>Neapolitan: </small><span title="Representation in the International Phonetic Alphabet (IPA)" lang="nap-Latn-fonipa">[ˈpittsə]</span>) is a dish of  Italian origin consisting of a usually round, flat base of leavened wheat-based dough topped with tomatoes, cheese, and often various other ingredients (such as various types of sausage, anchovies, mushrooms, onions, olives, vegetables, meat, ham, etc.), which is then baked at a high temperature, traditionally in a wood-fired oven. A small pizza is sometimes called a pizzetta. A person who makes pizza is known as a <b>pizzaiolo</b>.
# ...

# %% [markdown]
# ####**1. L'API Twitter et l'authentification**
#
# + ***Félicitations pour avoir interagi avec vos toutes premières API et en avoir obtenu des données ! Vous êtes sur la dernière ligne droite maintenant.***
#
# ####**2. Ici, vous apprendrez**
#
# + ***En tant que dernière plongée en profondeur, vous allez diffuser des données à partir de l'API Twitter. Vous apprendrez à filtrer les tweets entrants pour les mots-clés, vous découvrirez les principes de l'authentification API et OAuth.***
#
# ####**3. Ici, vous apprendrez***
# + ***Vous apprendrez également les bases du package tweepy, que de nombreuses personnes de PythonLand utilisent pour interagir avec l'API Twitter.***
#
# ####**4. Accédez à l'API Twitter**
#
# + ***L'une des premières différences majeures entre l'API Twitter et toutes les API que vous avez vues jusqu'à présent est que vous pouviez accéder à toutes les autres de manière anonyme et Twitter exige que vous ayez un compte.***
#
# ####**5. Accédez à l'API Twitter**
#
# + ***Pour accéder à l'API Twitter, il faut créer un compte Twitter si vous n'en avez pas déjà un, connectez-vous aux applications Twitter et cliquez sur "Créer une nouvelle application" - vous devrez accepter une variété de termes et conditions ici, ensuite, rendez-vous dans votre onglet "Clés et jetons d'accès" et copiez votre clé API, votre secret API,votre jeton d'accès et le secret de votre jeton d'accès.***
#
# ####**6. Accédez à l'API Twitter**
#
# + ***Ce sont les identifiants d'authentification qui vous permettront d'accéder à l'API Twitter depuis Python.***
#
# #####**7. Accédez à l'API Twitter**
#
# + ***Dans les exercices interactifs suivants, nous n'exigerons pas que vous créiez votre propre compte Twitter et votre propre application : nous ferons une simulation de la façon dont vous diffuseriez des données et les analyseriez comme si vous l'aviez fait.***
#
# ####**8. Twitter a un certain nombre d'API**
#
# + ***Il est maintenant important de mentionner que Twitter a un certain nombre d'API. Premièrement, ils ont une API REST ; nous n'entrerons pas dans les détails sanglants des API REST ici, mais je dirai deux choses - une : REST est l'abréviation de Representational State Transfer ; deux : l'API REST de Twitter permet à l'utilisateur de "lire et écrire des données Twitter".***
#
# ####**9. Twitter a un certain nombre d'API**
#
# +  ***Afin de "surveiller ou traiter les Tweets en temps réel",c'est-à-dire pour diffuser des données Twitter, cependant, nous voudrons utiliser l'API Streaming de Twitter.***
#
# ####**10. Twitter a un certain nombre d'API**
#
# + ***En particulier, nous utiliserons le flux public, que la documentation de l'API de Twitter définit comme "flux de données publiques circulant via Twitter". Le flux public lui-même contient un certain nombre d'options.***
#
# ####**11. Twitter a un certain nombre d'API**
#
# + ***Comme nous voulons lire et traiter les tweets, nous voudrons utiliser l'API GET statuses/sample, qui "renvoie un petit échantillon aléatoire de tous les statuts publics".***
#
# ####**12. Twitter a un certain nombre d'API**
#
# + ***Si vous vouliez accéder absolument à "Tous les statuts publics", vous auriez besoin d'utiliser l'API Firehose de Twitter, qui n'est pas accessible au public et vous coûterait très probablement un joli centime.***
#
# ####**13. Les tweets sont renvoyés au format JSON**
#
# + ***Un dernier point à noter avant de commencer à diffuser des tweets : les tweets nous sont renvoyés sous forme de JSON et ils contiennent de nombreux champs possibles.***
#
# ####**14. Les tweets sont renvoyés au format JSON**
#
# + ***Consultez le guide de champ Twitter Twitter ici. Vous pouvez obtenir le texte du tweet, l'utilisateur, la langue, l'heure du tweet, parmi bien d'autres domaines. Voyons maintenant comment accéder et diffuser des données depuis l'API Twitter !***
#
# ####**15. Utiliser Tweepy : Authentification**
#
# + ***Pour les premiers streamers de tweet Python, je recommande généralement le package tweepy, qui a un bon équilibre entre convivialité et capacité. Utilisons-le maintenant pour diffuser des tweets ! Tout d'abord, nous devons créer des variables pour stocker notre jeton d'accès et notre secret, ainsi que notre clé client et notre secret.***
#
# ####**16. Utiliser Tweepy : diffuser des tweets !!**
#
# + ***Pour diffuser, nous créons une instance de la classe Stream de tweepy, en transmettant notre clé consommateur, notre secret consommateur, notre jeton d'accès et notre secret de jeton d'accès. Vous pouvez ensuite diffuser des tweets contenant des mots-clés de votre choix en appliquant la méthode de filtrage au flux d'objets ! Dans les exercices suivants, vous vous entraînerez à écrire du code Python pour diffuser des tweets, puis vous effectuerez une analyse de base de ces tweets pour voir à quelle fréquence des mots-clés particuliers sont mentionnés.***
#
# ####**17. Entraînons-nous !**
#
# + ***Apprécier!***

# %% [markdown]
# ###**exercices**
#
# ####**Tweets en streaming**
# + ***Il est temps de streamer quelques tweets ! Votre tâche consiste à créer l' Streamobjet et à filtrer les tweets en fonction de mots-clés particuliers. tweepy a été importé pour vous.***
#
# ####**Instructions**
#
# + Créez votre objet Stream avec les informations d'identification fournies.
# + Filtrez votre variable Stream pour les mots-clés "clinton", "trump", "sanders"et "cruz".

# %%
# Twitter App
# https://developer.twitter.com/en/apps
# !pip install tweepy

# %%
import tweepy

# %%
# Store credentials in relevant variables
consumer_key = "nZ6EA0FxZ293SxGNg8g8aP0HM"
consumer_secret = "fJGEodwe3KiKUnsYJC3VRndj7jevVvXbK2D5EiJ2nehafRgA6i"
access_token = "1092294848-aHN7DcRP9B4VMTQIhwqOYiB14YkW92fFO8k8EPy"
access_token_secret = "X4dHmhPfaksHcQ7SCbmZa2oYBBVSD2g8uIHXsp5CTaksx"

# Create your Stream object with credentials
stream = tweepy.Stream(consumer_key, consumer_secret, access_token, access_token_secret)

# Filter your Stream variable
stream.filter(track=["clinton", "trump", "sanders", "cruz"])

# %%
# funcion MyStreamListener
# https://gist.github.com/hugobowne/18f1c0c0709ed1a52dc5bcd462ac69f4

# %% [markdown]
# ####**Chargez et explorez vos données Twitter**
#
# + ***Maintenant que vous avez vos données Twitter stockées localement dans un fichier texte, il est temps de l'explorer ! C'est ce que vous ferez dans les prochains exercices interactifs. Dans cet exercice, vous allez lire les données Twitter dans une liste : tweets_data.***
#
# + *Sachez qu'il s'agit de données réelles de Twitter et qu'il existe donc toujours un risque qu'elles contiennent des blasphèmes ou d'autres contenus offensants (dans cet exercice et dans tous les exercices suivants qui utilisent également de véritables données Twitter).*
#
# ####**Instructions**
#
# + Attribuez le nom du fichier 'tweets.txt'à la variable tweets_data_path.
# + Initialiser tweets_data en tant que liste vide pour stocker les tweets.
# + Dans la boucle for initiée par for line in tweets_file:, chargez chaque tweet dans une variable, tweet, en utilisant `json.loads()`, puis ajoutez tweet à tweets_data en utilisant la méthode `append()`.
# + Appuyez sur soumettre et consultez les clés du premier dictionnaire de tweet imprimé sur le shell.

# %%
# Import package
import json

# String of path to file: tweets_data_path
tweets_data_path='/content/assets.datacamp.com_production_repositories_488_datasets_3ef452f83a91556ea4284624b969392c0506fb33_tweets3.txt'

# Initialize empty list to store tweets: tweets_data
tweets_data = []

# Open connection to file
tweets_file = open(tweets_data_path, "r")

# Read in tweets and store in list: tweets_data
for line in tweets_file:
    tweet=json.loads(line)
    tweets_data.append(tweet)

# Close connection to file
tweets_file.close()

# Print the keys of the first tweet dict
print(tweets_data[0].keys())
# Out:
# dict_keys(['in_reply_to_user_id', 'created_at', 'filter_level', 'truncated', 'possibly_sensitive', 'timestamp_ms', 'user', 'text', 'extended_entities', 'in_reply_to_status_id', 'entities', 'favorited', 'retweeted', 'is_quote_status', 'id', 'favorite_count', 'retweeted_status', 'in_reply_to_status_id_str', 'in_reply_to_user_id_str', 'id_str', 'in_reply_to_screen_name', 'coordinates', 'lang', 'place', 'contributors', 'geo', 'retweet_count', 'source'])

# %% [markdown]
# ####**Données Twitter vers DataFrame**
#
# + ***Vous avez maintenant les données Twitter dans une liste de dictionnaires, tweets_data, où chaque dictionnaire correspond à un seul tweet. Ensuite, vous allez extraire le texte et la langue de chaque tweet. Le texte d'un tweet, t1, est stocké en tant que valeur t1['text']; de même, la langue est stockée dans t1['lang']. Votre tâche consiste à créer un DataFrame dans lequel chaque ligne est un tweet et les colonnes sont 'text'et 'lang'.***
#
# ####**Instructions**
#
# + Utiliser pd.DataFrame() pour construire un DataFrame de textes et de langues de tweet ; pour ce faire, le premier argument doit être tweets_data, une liste de dictionnaires.
# + Le deuxième argument de pd.DataFrame() est une liste des clés que vous souhaitez avoir en colonnes. Attribuez le résultat de l'appel pd.DataFrame() à df.
# + Imprimez la tête du DataFrame.

# %%
# Import package
import pandas as pd

# Build DataFrame of tweet texts and languages
df = pd.DataFrame(tweets_data, columns=['text', 'lang'])

# Print head of DataFrame
print(df.head())
# Out:
#                                                 text lang
# 0  RT @bpolitics: .@krollbondrating's Christopher...   en
# 1  RT @HeidiAlpine: @dmartosko Cruz video found.....   en
# 2  Njihuni me Zonjën Trump !!! | Ekskluzive https...   et
# 3  Your an idiot she shouldn't have tried to grab...   en
# 4  RT @AlanLohner: The anti-American D.C. elites ...   en

# %% [markdown]
# ####**Un peu d'analyse de texte Twitter**
#
# + ***Maintenant que vous avez configuré votre DataFrame de tweets , vous allez effectuer une petite analyse de texte pour compter le nombre de tweets contenant les mots 'clinton', 'trump', 'sanders' et 'cruz'.****
#
# + ***Dans le code de pré-exercice, nous avons défini la fonction word_in_text() suivante , qui vous dira si le premier argument (un mot) apparaît dans le 2ème argument (un tweet).***
#
#         import re
#
#         def word_in_text(word, text):
#             word = word.lower()
#             text = text.lower()
#             match = re.search(word, text)
#
#         if match:
#             return True
#         return False
#
#
# + *Vous allez parcourir les lignes du DataFrame et calculer combien de tweets contiennent chacun de nos mots-clés ! La liste des objets pour chaque candidat a été initialisée à 0.*
#
# ####**Instructions**
#
# + Dans la boucle  for index, row in df.iterrows():, le code augmente actuellement la valeur de clintonchaque 1fois qu'un tweet (ligne de texte) mentionnant 'Clinton' est rencontré ; complétez le code afin que la même chose se produise pour trump, sanderset cruz.

# %%
import re

def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)

    if match:
        return True
    return False

# %%
# Initialize list to store tweet counts
[clinton, trump, sanders, cruz] = [0, 0, 0, 0]

# Iterate through df, counting the number of tweets in which
# each candidate is mentioned
for index, row in df.iterrows():
    clinton += word_in_text('clinton', row['text'])
    trump += word_in_text('trump', row['text'])
    sanders += word_in_text('sanders', row['text'])
    cruz += word_in_text('cruz', row['text'])

# %% [markdown]
# ####**Tracer vos données Twitter**
#
# + ***Maintenant que vous avez le nombre de tweets dans lesquels chaque candidat a été mentionné, vous pouvez tracer un graphique à barres de ces données. Vous utiliserez la bibliothèque de visualisation de données statistiques seaborn, que vous n'avez peut-être jamais vue auparavant, mais nous vous guiderons tout au long. Vous allez d'abord importer seabornen tant que sns. Vous construirez ensuite un barplot des données à l'aide de sns.barplot, en lui transmettant deux arguments :***
#
#   + une liste d' étiquettes et
#   + une liste contenant les variables que vous souhaitez tracer ( clinton, trumpetc.)
#
# + *Espérons que vous verrez que Trump a été représenté de manière déraisonnable ! Nous avons déjà exécuté les solutions d'exercice précédentes dans votre environnement.*
#
# ####**Instructions**
#
# + Importez à la fois matplotlib.pyplot et seaborn en utilisant les alias pltet sns, respectivement.
# + Complétez les arguments de sns.barplot:
# + Le premier argument doit être la liste des étiquettes à afficher sur l'axe des $x$ (créé à l'étape précédente).
# + Le deuxième argument doit être une liste des variables que vous souhaitez tracer, comme produit dans l'exercice précédent (c'est-à-dire une liste contenant clinton, trump, etc.).

# %%
# Import packages
import  matplotlib.pyplot as plt
import seaborn as sns 

# Set seaborn style
sns.set(color_codes=True)

# Create a list of labels:cd
cd = ['clinton', 'trump', 'sanders', 'cruz']

# Plot the bar chart
ax = sns.barplot(x= cd, y=[clinton, trump, sanders, cruz])
ax.set(ylabel="count")
plt.show()

# %% [markdown]
# ####**1. Réflexions finales**
#
# + ***Waouh félicitations ! Vous venez de terminer votre plongée en profondeur dans l'API Twitter, dans laquelle vous avez diffusé des tweets, les avez traités et visualisez vos résultats. Incroyable! Si vous êtes arrivé jusqu'ici,***
#
# ####**2. Ce que vous avez appris :**
#
# + ***vous pouvez désormais importer des données en Python à partir d'un large éventail de sources. Pour récapituler les compétences et les compétences d'importation de données que vous avez acquises dans ce cours ET sa préquelle, vous êtes maintenant apte à importer des fichiers texte de base et des fichiers plats, le pain et le beurre de base de la vie professionnelle de tout scientifique de données, fichiers locaux dans d'autres formats, tels que des feuilles de calcul Excel, des fichiers SAS, Stata et MATLAB, des fichiers marinés et HDF5. Ces compétences feront de vous un collaborateur encore meilleur pour de nombreux professionnels en activité. Vous avez développé vos compétences de base dans l'écriture de requêtes SQL et pouvez désormais extraire tous les types de données des bases de données relationnelles. Vous pouvez extraire des données du Web : non seulement vous pouvez importer des fichiers Web de base, mais vous connaissez plusieurs façons d'émettre des requêtes GET et vous pouvez même faire du scraping Web de base et de l'analyse HTML ! En plus de tout cela, vous avez appris à extraire des données des API et avez acquis une expérience pratique en vous plongeant dans plusieurs exemples. Vous avez beaucoup appris et***
#
# ####**3. Entraînons-nous !**
#
# + ***terminé avec succès ces deux cours sur l'importation de données en Python. Bonne importation !***
